# %% [markdown]
# <a class="anchor" id="About_Data"></a>
# # <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 20px 20px;overflow:hidden;font-weight:500">Sales and Trends 💰💳</p>

# %% [markdown]
# <img src="https://media4.giphy.com/media/xT5LMWNOjGqJzUfyve/giphy.gif?cid=6c09b952nekr3sh40t51ojn7r6b54j9tdqy2cpeonwahc2fr&ep=v1_internal_gif_by_id&rid=giphy.gif&ct=g" width="90%" height="100%">

# %% [markdown]
# <a class="anchor" id="About_Data"></a>
# # <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Introduction  📬</p>

# %% [markdown]
# <div style = 'border : 5px solid #0c4da3; background-color:lightred;padding:10px'>
#
# This project uses `Sales and Trends Dataset`.
#
# - TransactionID (Unique identifier for each transaction)
# - Date (Date of the transaction, format: YYYY-MM-DD)
# - Time (Time of the transaction, format: HH:MM:SS)
# - CustomerID (Unique identifier for each customer)
# - Age (Age of the customer)
# - Gender (Gender of the customer: Male, Female, Other)
# - Location (City or town where the purchase was made)
# - StoreID (Unique identifier for the store, if applicable)
# - OnlineOrderFlag (Boolean: True if online, False if in-store)
# - ProductID (Unique identifier for the product)
# - ProductName (Name of the product)
# - Category (Category of the product, e.g., Electronics, Clothing, Toys, Food, Decorations)
# - Quantity (Number of items purchased in the transaction)
# - UnitPrice (Price per unit of the product)
# - TotalPrice (Total price for the product, calculated as Quantity * UnitPrice)
# - PaymentType (Type of payment, e.g., Credit Card, Debit Card, Cash, Online Payment)
# - Promotion Applied (Boolean: True if any promotion was applied, False otherwise)
# - DiscountAmount (The amount of discount, if any)
# - GiftWrap (Boolean: True if the product was gift-wrapped, False otherwise)
# - ShippingMethod (Method of shipping, e.g., Standard, Express, Overnight, if online)
# - Delivery Time (Number of days taken for delivery, if online)
# - Weather (General weather condition on the day of purchase, e.g., Snowy, Rainy, Sunny)
# - Event (Special events on the purchase day, e.g., Christmas Market, Black Friday)
# - Customer Satisfaction (Customer satisfaction rating, on a scale of 1-5)
# - Return Flag (Boolean: True if the product was returned, False otherwise)

# %% [markdown]
# <a class="anchor" id="Cleaning_Data"></a>
# # <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 15px;overflow:hidden;font-weight:500">Data Cleaning  🔍🛠</p>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from pywaffle.waffle import Waffle

import warnings
warnings.simplefilter("ignore")

# %%
Sales = pd.read_excel("Sales and Trends.xlsx")

# %%
Sales.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_62b5f_row0_col0, #T_62b5f_row0_col9, #T_62b5f_row0_col17, #T_62b5f_row1_col12, #T_62b5f_row1_col14, #T_62b5f_row1_col17, #T_62b5f_row1_col20, #T_62b5f_row2_col3, #T_62b5f_row2_col4, #T_62b5f_row2_col13, #T_62b5f_row2_col17, #T_62b5f_row3_col17, #T_62b5f_row3_col23, #T_62b5f_row4_col7, #T_62b5f_row4_col17 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_62b5f_row0_col3, #T_62b5f_row0_col12, #T_62b5f_row0_col13, #T_62b5f_row0_col14, #T_62b5f_row0_col20, #T_62b5f_row0_col23, #T_62b5f_row1_col9, #T_62b5f_row3_col4, #T_62b5f_row3_col7, #T_62b5f_row3_col12, #T_62b5f_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_62b5f_row0_col4 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_62b5f_row0_col7, #T_62b5f_row1_col7, #T_62b5f_row2_col20, #T_62b5f_row3_col20, #T_62b5f_row4_col20 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# ...

# %%
Sales.shape
# Out:
# (10000, 25)

# %%
Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionID         10000 non-null  int64
#  1   Date                  10000 non-null  datetime64[ns]
#  2   Time                  10000 non-null  object
#  3   CustomerID            10000 non-null  int64
#  4   Age                   10000 non-null  int64
#  5   Gender                10000 non-null  object
#  6   Location              10000 non-null  object
#  7   StoreID               4582 non-null   float64
#  8   OnlineOrderFlag       10000 non-null  bool
#  9   ProductID             10000 non-null  int64
#  10  ProductName           10000 non-null  object
#  11  Category              10000 non-null  object
#  12  Quantity              10000 non-null  int64
#  13  UnitPrice             10000 non-null  float64
#  14  TotalPrice            10000 non-null  float64
# ...

# %%
Sales.dtypes
# Out:
# TransactionID                    int64
# Date                    datetime64[ns]
# Time                            object
# CustomerID                       int64
# Age                              int64
# Gender                          object
# Location                        object
# StoreID                        float64
# OnlineOrderFlag                   bool
# ProductID                        int64
# ProductName                     object
# Category                        object
# Quantity                         int64
# UnitPrice                      float64
# TotalPrice                     float64
# PaymentType                     object
# PromotionApplied                  bool
# DiscountAmount                 float64
# GiftWrap                          bool
# ShippingMethod                  object
# DeliveryTime                   float64
# Weather                         object
# Event                           object
# CustomerSatisfaction             int64
# ...

# %%
Sales.isnull().sum()
# Out:
# TransactionID              0
# Date                       0
# Time                       0
# CustomerID                 0
# Age                        0
# Gender                     0
# Location                   0
# StoreID                 5418
# OnlineOrderFlag            0
# ProductID                  0
# ProductName                0
# Category                   0
# Quantity                   0
# UnitPrice                  0
# TotalPrice                 0
# PaymentType                0
# PromotionApplied           0
# DiscountAmount             0
# GiftWrap                   0
# ShippingMethod          4582
# DeliveryTime            4582
# Weather                    0
# Event                      0
# CustomerSatisfaction       0
# ReturnFlag                 0
# dtype: int64

# %%
Sales = Sales.drop(
   ['StoreID','ShippingMethod','DeliveryTime'],
   axis=1 )

# %%
categorical = Sales.select_dtypes(['category', 'object']).columns 
for col in categorical:
    print('{} : {} unique value(s)'.format(col, Sales[col].nunique()))
# Out:
# Time : 9455 unique value(s)
# Gender : 3 unique value(s)
# Location : 20 unique value(s)
# ProductName : 5 unique value(s)
# Category : 5 unique value(s)
# PaymentType : 4 unique value(s)
# Weather : 3 unique value(s)
# Event : 3 unique value(s)

# %%
Sales.duplicated().sum()
# Out:
# 0

# %%
Sales.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_bff6b_row0_col0, #T_bff6b_row0_col8, #T_bff6b_row0_col16, #T_bff6b_row1_col11, #T_bff6b_row1_col13, #T_bff6b_row1_col16, #T_bff6b_row2_col3, #T_bff6b_row2_col4, #T_bff6b_row2_col12, #T_bff6b_row2_col16, #T_bff6b_row3_col16, #T_bff6b_row3_col20, #T_bff6b_row4_col16 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bff6b_row0_col3, #T_bff6b_row0_col11, #T_bff6b_row0_col12, #T_bff6b_row0_col13, #T_bff6b_row0_col20, #T_bff6b_row1_col8, #T_bff6b_row3_col4, #T_bff6b_row3_col11, #T_bff6b_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bff6b_row0_col4 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_bff6b_row1_col0, #T_bff6b_row1_col20, #T_bff6b_row2_col11, #T_bff6b_row3_col12 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_bff6b_row1_col3, #T_bff6b_row2_col20, #T_bff6b_row3_col0, #T_bff6b_row4_col20 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_bff6b_row1_col4 {
# ...

# %% [markdown]
# <a class="anchor" id="About_Data"></a>
# # <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Columns :</p>

# %% [markdown]
# - ### Date Column:

# %%
Sales['Date'] = Sales['Date'] .astype('str')

# %%
Sales.insert(2,'Year',0)
Sales['Year'] = Sales['Date'].str[:4]
Sales['Year'] = Sales['Year'].astype('int64')

# %%
Sales.insert(3,'Month',0)
Sales['Month'] = Sales['Date'].str[5:7]
Sales['Month'] = Sales['Month'].astype('int64')

# %%
Sales.insert(4,'Day',0)
Sales['Day'] = Sales['Date'].str[8:]
Sales['Day'] = Sales['Day'].astype('int64')

# %%
Sales['Month'] = Sales['Month'].replace({1:'Jan' ,2:'Feb' ,3:'Mar', 4:'Apr',5:'May',6:'June',7:'July',8:'Aug',9:'Sept',10:'Oct',11:'Nov',12:'Dec'})

# %%
Sales.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_78907_row0_col0, #T_78907_row0_col11, #T_78907_row0_col19, #T_78907_row1_col14, #T_78907_row1_col16, #T_78907_row1_col19, #T_78907_row2_col6, #T_78907_row2_col7, #T_78907_row2_col15, #T_78907_row2_col19, #T_78907_row3_col2, #T_78907_row3_col4, #T_78907_row3_col19, #T_78907_row3_col23, #T_78907_row4_col4, #T_78907_row4_col19 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_78907_row0_col2, #T_78907_row2_col0, #T_78907_row4_col2, #T_78907_row4_col14 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_78907_row0_col4 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_78907_row0_col6, #T_78907_row0_col14, #T_78907_row0_col15, #T_78907_row0_col16, #T_78907_row0_col23, #T_78907_row1_col2, #T_78907_row1_col11, #T_78907_row2_col4, #T_78907_row3_col7, #T_78907_row3_col14, #T_78907_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_78907_row0_col7 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# ...

# %%
Sales = Sales.drop(labels =
   'Date',
   axis=1 )

# %% [markdown]
# - ### Time column:

# %%
Sales['Time'] = Sales['Time'] .astype('str')

# %%
Sales.insert(5,'Hour',0)
Sales['Hour'] = Sales['Time'].str[:2]
Sales['Hour'] = Sales['Hour'].astype('int64')

# %%
Sales.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_3ec71_row0_col0, #T_3ec71_row0_col11, #T_3ec71_row0_col19, #T_3ec71_row1_col14, #T_3ec71_row1_col16, #T_3ec71_row1_col19, #T_3ec71_row2_col6, #T_3ec71_row2_col7, #T_3ec71_row2_col15, #T_3ec71_row2_col19, #T_3ec71_row3_col1, #T_3ec71_row3_col3, #T_3ec71_row3_col19, #T_3ec71_row3_col23, #T_3ec71_row4_col3, #T_3ec71_row4_col5, #T_3ec71_row4_col19 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3ec71_row0_col1, #T_3ec71_row2_col0, #T_3ec71_row4_col1, #T_3ec71_row4_col14 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_3ec71_row0_col3 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_3ec71_row0_col5 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_3ec71_row0_col6, #T_3ec71_row0_col14, #T_3ec71_row0_col15, #T_3ec71_row0_col16, #T_3ec71_row0_col23, #T_3ec71_row1_col1, #T_3ec71_row1_col11, #T_3ec71_row2_col3, #T_3ec71_row3_col5, #T_3ec71_row3_col7, #T_3ec71_row3_col14, #T_3ec71_row4_col0 {
# ...

# %%
Sales.insert(6,'Daytime','')
Sales.loc[(Sales['Hour'] >= 6) & (Sales['Hour'] <= 11),'Daytime'] = 'Morning'
Sales.loc[(Sales['Hour'] >= 12) & (Sales['Hour'] <= 17),'Daytime'] = 'Afternoon'
Sales.loc[(Sales['Hour'] >= 18) & (Sales['Hour'] <= 21),'Daytime'] = 'Evening'
Sales.loc[(Sales['Hour'] >= 22) | (Sales['Hour'] <= 5),'Daytime'] = 'Night'

# %%
Sales.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_d5af1_row0_col0, #T_d5af1_row0_col12, #T_d5af1_row0_col20, #T_d5af1_row1_col15, #T_d5af1_row1_col17, #T_d5af1_row1_col20, #T_d5af1_row2_col7, #T_d5af1_row2_col8, #T_d5af1_row2_col16, #T_d5af1_row2_col20, #T_d5af1_row3_col1, #T_d5af1_row3_col3, #T_d5af1_row3_col20, #T_d5af1_row3_col24, #T_d5af1_row4_col3, #T_d5af1_row4_col5, #T_d5af1_row4_col20 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d5af1_row0_col1, #T_d5af1_row2_col0, #T_d5af1_row4_col1, #T_d5af1_row4_col15 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_d5af1_row0_col3 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_d5af1_row0_col5 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_d5af1_row0_col7, #T_d5af1_row0_col15, #T_d5af1_row0_col16, #T_d5af1_row0_col17, #T_d5af1_row0_col24, #T_d5af1_row1_col1, #T_d5af1_row1_col12, #T_d5af1_row2_col3, #T_d5af1_row3_col5, #T_d5af1_row3_col8, #T_d5af1_row3_col15, #T_d5af1_row4_col0 {
# ...

# %%
Sales = Sales.drop(labels =
   'Time',
   axis=1 )

# %%
Sales.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_f8d03_row0_col0, #T_f8d03_row0_col11, #T_f8d03_row0_col19, #T_f8d03_row1_col14, #T_f8d03_row1_col16, #T_f8d03_row1_col19, #T_f8d03_row2_col6, #T_f8d03_row2_col7, #T_f8d03_row2_col15, #T_f8d03_row2_col19, #T_f8d03_row3_col1, #T_f8d03_row3_col3, #T_f8d03_row3_col19, #T_f8d03_row3_col23, #T_f8d03_row4_col3, #T_f8d03_row4_col4, #T_f8d03_row4_col19 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f8d03_row0_col1, #T_f8d03_row2_col0, #T_f8d03_row4_col1, #T_f8d03_row4_col14 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_f8d03_row0_col3 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_f8d03_row0_col4 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_f8d03_row0_col6, #T_f8d03_row0_col14, #T_f8d03_row0_col15, #T_f8d03_row0_col16, #T_f8d03_row0_col23, #T_f8d03_row1_col1, #T_f8d03_row1_col11, #T_f8d03_row2_col3, #T_f8d03_row3_col4, #T_f8d03_row3_col7, #T_f8d03_row3_col14, #T_f8d03_row4_col0 {
# ...

# %% [markdown]
# - ### Age column:

# %%
Sales['Age'].unique()
# Out:
# array([27, 43, 25, 64, 26, 18, 63, 48, 58, 41, 50, 51, 20, 62, 66, 23, 44,
#        52, 37, 56, 35, 55, 61, 54, 24, 67, 28, 69, 39, 45, 59, 42, 34, 33,
#        57, 68, 22, 36, 47, 31, 46, 49, 53, 30, 19, 40, 29, 32, 70, 21, 60,
#        65, 38], dtype=int64)

# %%
Sales['Age'].describe()
# Out:
# count    10000.000000
# mean        43.791700
# std         15.366585
# min         18.000000
# 25%         30.000000
# 50%         44.000000
# 75%         57.000000
# max         70.000000
# Name: Age, dtype: float64

# %%
Sales.insert(8,'Age Bracket','')
Sales.loc[(Sales['Age'] >= 18) & (Sales['Age'] <= 20),'Age Bracket'] = 'Adolescence'
Sales.loc[(Sales['Age'] >= 21) & (Sales['Age'] <= 35),'Age Bracket'] = 'Early Adulthood'
Sales.loc[(Sales['Age'] >= 36) & (Sales['Age'] <= 50),'Age Bracket'] = 'Middle Age'
Sales.loc[(Sales['Age'] >= 51) & (Sales['Age'] <= 70),'Age Bracket'] = 'Mature Adulthood'

# %%
Sales.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_08364_row0_col0, #T_08364_row0_col12, #T_08364_row0_col20, #T_08364_row1_col15, #T_08364_row1_col17, #T_08364_row1_col20, #T_08364_row2_col6, #T_08364_row2_col7, #T_08364_row2_col16, #T_08364_row2_col20, #T_08364_row3_col1, #T_08364_row3_col3, #T_08364_row3_col20, #T_08364_row3_col24, #T_08364_row4_col3, #T_08364_row4_col4, #T_08364_row4_col20 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_08364_row0_col1, #T_08364_row2_col0, #T_08364_row4_col1, #T_08364_row4_col15 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_08364_row0_col3 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_08364_row0_col4 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_08364_row0_col6, #T_08364_row0_col15, #T_08364_row0_col16, #T_08364_row0_col17, #T_08364_row0_col24, #T_08364_row1_col1, #T_08364_row1_col12, #T_08364_row2_col3, #T_08364_row3_col4, #T_08364_row3_col7, #T_08364_row3_col15, #T_08364_row4_col0 {
# ...

# %% [markdown]
# - ### Gender Column:

# %%
Sales['Gender'].unique()
# Out:
# array(['Other', 'Male', 'Female'], dtype=object)

# %%
Sales['Gender'].value_counts()
# Out:
# Male      3385
# Other     3317
# Female    3298
# Name: Gender, dtype: int64

# %%
gender_size = (Sales.groupby('Gender').size() * 100 / len(Sales)).to_dict()

# Define labels for the sexes
gender_labels = {'Female',  'Male', 'Other'}

# Create the figure
fig = plt.figure(
    FigureClass=Waffle,  # Use Waffle chart
    rows=5,  # Number of rows of people
    figsize=(9, 3),
    values=gender_size,  # Data

    # Colors for male, female, and other 
    colors=("#DE66AA", "#1E90FE", "#A9A9A9"),  # Example: gray for 'other'

    # Icons set to female, male, and star for other
    icons=['female', 'male', 'star'],  # Unicode star symbol for 'other'

    # Legend properties
    legend={'loc': 'lower center',  # Position of legend
            'bbox_to_anchor': (0.5, -0.5),  # Position relative to the plot
            'ncol': len(gender_size),  # Number of columns in legend
            'framealpha': 0,  # Transparency of legend frame
            'fontsize': 20  # Font size of legend labels
            },

    icon_size=20,  # Size of icons (hearts)

    icon_legend=True,  # Add icon to the legend at the bottom

    title={  # Title of the Waffle chart
        'label': 'Gender Distribution',  # Title text
        'loc': 'center',  # Position of title
        'fontdict': {'fontsize': 20}  # Font size of title
    }
)

plt.show()
# Out:
# <Waffle size 900x300 with 1 Axes>

# %% [markdown]
# - ### Location

# %%
Sales['Location'].unique()
# Out:
# array(['City_15', 'City_13', 'City_7', 'City_20', 'City_10', 'City_4',
#        'City_3', 'City_1', 'City_19', 'City_16', 'City_5', 'City_11',
#        'City_2', 'City_17', 'City_14', 'City_12', 'City_9', 'City_6',
#        'City_8', 'City_18'], dtype=object)

# %%
Sales['Location'].value_counts().T
# Out:
# City_13    550
# City_12    517
# City_18    516
# City_1     516
# City_14    515
# City_4     512
# City_3     511
# City_8     508
# City_19    508
# City_15    505
# City_6     503
# City_11    499
# City_2     499
# City_5     497
# City_20    492
# City_9     487
# City_16    480
# City_10    479
# City_7     458
# City_17    448
# Name: Location, dtype: int64

# %% [markdown]
# - ### ProductName

# %%
Sales['ProductName'].unique()
# Out:
# array(['Toys_Product', 'Clothing_Product', 'Decorations_Product',
#        'Food_Product', 'Electronics_Product'], dtype=object)

# %%
Sales['ProductName'].value_counts().T
# Out:
# Electronics_Product    2053
# Toys_Product           2011
# Decorations_Product    1995
# Food_Product           1991
# Clothing_Product       1950
# Name: ProductName, dtype: int64

# %% [markdown]
# - ### Category

# %%
Sales['Category'].unique()
# Out:
# array(['Toys', 'Clothing', 'Decorations', 'Food', 'Electronics'],
#       dtype=object)

# %%
Sales['Category'].value_counts().T
# Out:
# Electronics    2053
# Toys           2011
# Decorations    1995
# Food           1991
# Clothing       1950
# Name: Category, dtype: int64

# %%
Sales.describe(include='O').T
# Out:
#              count unique                  top  freq
# Month        10000      2                  Dec  5045
# Daytime      10000      4                Night  3300
# Age Bracket  10000      4     Mature Adulthood  3738
# Gender       10000      3                 Male  3385
# Location     10000     20              City_13   550
# ProductName  10000      5  Electronics_Product  2053
# Category     10000      5          Electronics  2053
# PaymentType  10000      4                 Cash  2540
# Weather      10000      3                Rainy  3408
# Event        10000      3         Black Friday  4254

# %%
Sales.describe().style.background_gradient(cmap = "Blues")
# Out:
# <style type="text/css">
# #T_1f218_row0_col0, #T_1f218_row0_col1, #T_1f218_row0_col2, #T_1f218_row0_col3, #T_1f218_row0_col4, #T_1f218_row0_col5, #T_1f218_row0_col6, #T_1f218_row0_col7, #T_1f218_row0_col8, #T_1f218_row0_col9, #T_1f218_row0_col10, #T_1f218_row0_col11, #T_1f218_row7_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1f218_row1_col0, #T_1f218_row5_col0 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_1f218_row1_col1, #T_1f218_row3_col1, #T_1f218_row4_col1, #T_1f218_row5_col1, #T_1f218_row6_col1, #T_1f218_row7_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# ...

# %%
Sales.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_72c66_row0_col0, #T_72c66_row0_col12, #T_72c66_row0_col20, #T_72c66_row1_col15, #T_72c66_row1_col17, #T_72c66_row1_col20, #T_72c66_row2_col6, #T_72c66_row2_col7, #T_72c66_row2_col16, #T_72c66_row2_col20, #T_72c66_row3_col1, #T_72c66_row3_col3, #T_72c66_row3_col20, #T_72c66_row3_col24, #T_72c66_row4_col3, #T_72c66_row4_col4, #T_72c66_row4_col20 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_72c66_row0_col1, #T_72c66_row2_col0, #T_72c66_row4_col1, #T_72c66_row4_col15 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_72c66_row0_col3 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_72c66_row0_col4 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_72c66_row0_col6, #T_72c66_row0_col15, #T_72c66_row0_col16, #T_72c66_row0_col17, #T_72c66_row0_col24, #T_72c66_row1_col1, #T_72c66_row1_col12, #T_72c66_row2_col3, #T_72c66_row3_col4, #T_72c66_row3_col7, #T_72c66_row3_col15, #T_72c66_row4_col0 {
# ...

# %% [markdown]
# - ## Product Sales Distribution

# %%
product_counts = Sales['ProductName'].value_counts()

# Create a blue color palette
num_products = len(product_counts)
blue_colors = plt.cm.Blues([i / num_products for i in range(num_products)])  # Generate a list of blue colors

# Create a pie chart for product distribution
plt.figure(figsize=(8, 8))

# Plot the pie chart
plt.pie(product_counts, labels=product_counts.index, autopct='%1.1f%%', startangle=90, colors=blue_colors)

# Add a title
plt.title('Product Distribution', fontsize=18)

# Ensure equal aspect ratio so the pie is circular
plt.axis('equal')

# Display the plot
plt.show()

# %% [markdown]
# - ## Monthly Sales Over Time

# %%
# Ensure the 'Month' column is numeric
Sales['Month'] = Sales['Month'].apply(lambda x: pd.to_datetime(x, format='%b').month if isinstance(x, str) else x)

# Count monthly sales
monthly_sales = Sales.groupby(['Year', 'Month'])['TotalPrice'].sum().reset_index()

# Create a date for plotting
monthly_sales['Date'] = pd.to_datetime(monthly_sales[['Year', 'Month']].assign(DAY=1))

plt.figure(figsize=(12, 6))
plt.plot(monthly_sales['Date'], monthly_sales['TotalPrice'], marker='o', color='blue')
plt.title('Monthly Sales Over Time', fontsize=18)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Total Sales ($)', fontsize=14)
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# - ## Total sales by product

# %%
product_sales = Sales.groupby('ProductName')['TotalPrice'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
product_sales.plot(kind='bar', color='skyblue')
plt.title('Total Sales by Product', fontsize=18)
plt.xlabel('Product', fontsize=14)
plt.ylabel('Total Sales ($)', fontsize=14)
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# - ## Count the occurrences of each satisfaction level

# %%
satisfaction_counts = Sales['CustomerSatisfaction'].value_counts()

# Define a blue color palette
colors = ['#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78']  # You can adjust the colors here

plt.figure(figsize=(8, 8))
plt.pie(satisfaction_counts, labels=satisfaction_counts.index, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Customer Satisfaction Distribution', fontsize=18)
plt.axis('equal')
plt.show()

# %% [markdown]
# - ## Total sales by gender

# %%
gender_sales = Sales.groupby('Gender')['TotalPrice'].sum()

# Create the bar chart with specified colors
plt.figure(figsize=(8, 6))
gender_sales.plot(kind='bar', color=['pink', 'blue', 'gray'])  # Update to the specified colors
plt.title('Total Sales by Gender', fontsize=18)
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Total Sales ($)', fontsize=14)
plt.xticks(rotation=0)
plt.grid(axis='y')  # Only show grid lines for the y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# - ## Total sales by age bracket

# %%
age_sales = Sales.groupby('Age Bracket')['TotalPrice'].sum()

# Create a blue color palette with enough colors
num_colors = len(age_sales)
blue_colors = plt.cm.Blues([i / num_colors for i in range(num_colors)])  # Generates shades of blue

# Create the bar chart with the blue palette
plt.figure(figsize=(10, 6))
bars = plt.bar(age_sales.index, age_sales, color=blue_colors)  # Apply the blue colors

# Adding color to each bar explicitly (optional for debugging)
for bar in bars:
    bar.set_color(blue_colors[bars.index(bar) % num_colors])

plt.title('Total Sales by Age Bracket', fontsize=18)
plt.xlabel('Age Bracket', fontsize=14)
plt.ylabel('Total Sales ($)', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y')  # Only show grid lines for the y-axis
plt.tight_layout()
plt.show()
