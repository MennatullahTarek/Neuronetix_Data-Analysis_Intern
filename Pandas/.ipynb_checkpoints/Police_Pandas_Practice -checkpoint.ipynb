# %% [markdown]
# <a class="anchor" id="About_Data"></a>
# # <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 20px 20px;overflow:hidden;font-weight:500">Police 🚨👮‍♀</p>

# %% [markdown]
# <img src="https://media0.giphy.com/media/G825ArmDSn6Ue5g152/giphy.gif?cid=6c09b952m7vzpzgzjpmdnsq601p0jwqqiksohe8x8tzgbl0f&ep=v1_internal_gif_by_id&rid=giphy.gif&ct=g" width="100%" height="100%">

# %% [markdown]
# <a class="anchor" id="About_Data"></a>
# # <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Introduction  🚓</p>

# %% [markdown]
# <div style = 'border : 5px solid #0c4da3; background-color:lightred;padding:10px'>
#
# This project uses `Python's Pandas library` to clean and analyze
# [Police traffic Dataset](https://www.kaggle.com/datasets/melihkanbay/police/data).
#
# The goal is to `practice data analysis` by identifying and fixing issues like missing values and inconsistencies in the dataset.

# %% [markdown]
# <a class="anchor" id="Cleaning_Data"></a>
# # <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 15px;overflow:hidden;font-weight:500">Data Cleaning  🔍🛠</p>

# %%
import pandas as pd
import warnings
warnings.simplefilter("ignore")

# %%
police = pd.read_csv("police.csv")

# %%
police.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_2c89a_row0_col2, #T_2c89a_row1_col2, #T_2c89a_row2_col2, #T_2c89a_row3_col2, #T_2c89a_row4_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_2c89a_row0_col4 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_2c89a_row0_col5 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_2c89a_row1_col4, #T_2c89a_row3_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2c89a_row1_col5, #T_2c89a_row3_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2c89a_row2_col4 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_2c89a_row2_col5 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_2c89a_row4_col4 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_2c89a_row4_col5 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_2c89a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
police.shape
# Out:
# (91741, 15)

# %%
police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   county_name         0 non-null      float64
#  3   driver_gender       86406 non-null  object
#  4   driver_age_raw      86414 non-null  float64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86408 non-null  object
#  7   violation_raw       86408 non-null  object
#  8   violation           86408 non-null  object
#  9   search_conducted    91741 non-null  bool
#  10  search_type         3196 non-null   object
#  11  stop_outcome        86408 non-null  object
#  12  is_arrested         86408 non-null  object
#  13  stop_duration       86408 non-null  object
#  14  drugs_related_stop  91741 non-null  bool
# ...

# %%
police.dtypes
# Out:
# stop_date              object
# stop_time              object
# county_name           float64
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# search_type            object
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %%
police.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
police.describe().style.background_gradient(cmap = "Blues")
# Out:
# <style type="text/css">
# #T_82ff4_row0_col0, #T_82ff4_row1_col0, #T_82ff4_row1_col2, #T_82ff4_row2_col0, #T_82ff4_row2_col1, #T_82ff4_row2_col2, #T_82ff4_row3_col0, #T_82ff4_row3_col1, #T_82ff4_row3_col2, #T_82ff4_row4_col0, #T_82ff4_row4_col2, #T_82ff4_row5_col0, #T_82ff4_row5_col2, #T_82ff4_row6_col0, #T_82ff4_row6_col2, #T_82ff4_row7_col0, #T_82ff4_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_82ff4_row0_col1, #T_82ff4_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_82ff4_row1_col1, #T_82ff4_row4_col1, #T_82ff4_row5_col1, #T_82ff4_row6_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_82ff4_row7_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# </style>
# <table id="T_82ff4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82ff4_level0_col0" class="col_heading level0 col0" >county_name</th>
# ...

# %%
police.describe(include='O').T
# Out:
#                count unique                 top   freq
# stop_date      91741   3768          2012-01-11     69
# stop_time      91741   1436               11:00    323
# driver_gender  86406      2                   M  62895
# driver_race    86408      5               White  62158
# violation_raw  86408     12            Speeding  48463
# violation      86408      6            Speeding  48463
# search_type     3196     24  Incident to Arrest   1219
# stop_outcome   86408      6            Citation  77006
# is_arrested    86408      2               False  83479
# stop_duration  86408      5            0-15 Min  69543

# %% [markdown]
# <div style = 'border : 5px solid #0c4da3; background-color:lightred;padding:10px'>
#
# #### <u><span style="color:#08306B;">  Observation: </span></u>
#  - The police dataset consists of  `91741 rows` and `15 columns`.
#  - It has all `NAN` values in `"county_name"` column.
#  - There are some coloumns that have uncorrect data type.

# %%
police = police.drop(
    labels='county_name',
    axis=1)

# %%
police.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_ec09f_row0_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_ec09f_row0_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_ec09f_row1_col3, #T_ec09f_row3_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ec09f_row1_col4, #T_ec09f_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ec09f_row2_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_ec09f_row2_col4 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_ec09f_row4_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_ec09f_row4_col4 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_ec09f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec09f_level0_col0" class="col_heading level0 col0" >stop_date</th>
#       <th id="T_ec09f_level0_col1" class="col_heading level0 col1" >stop_time</th>
# ...

# %%
<a class="anchor" id="Cleaning_Data"></a>
# <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 15px;overflow:hidden;font-weight:500">Data Cleaning  🔍🛠</p>
# Out:
#   File "C:\Users\menat\AppData\Local\Temp\ipykernel_7232\172724457.py", line 1
#     <a class="anchor" id="Cleaning_Data"></a>
#     ^
# SyntaxError: invalid syntax

# %%
police.duplicated().sum()
# Out:
# 479

# %%
police.drop_duplicates(inplace = True)

# %%
police.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_c42b1_row0_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_c42b1_row0_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_c42b1_row1_col3, #T_c42b1_row3_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c42b1_row1_col4, #T_c42b1_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c42b1_row2_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_c42b1_row2_col4 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_c42b1_row4_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_c42b1_row4_col4 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_c42b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c42b1_level0_col0" class="col_heading level0 col0" >stop_date</th>
#       <th id="T_c42b1_level0_col1" class="col_heading level0 col1" >stop_time</th>
# ...

# %%
police.duplicated().sum()
# Out:
# 0

# %%
<a class="anchor" id="Cleaning_Data"></a>
# <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 15px;overflow:hidden;font-weight:500">Data Cleaning  🔍🛠</p>

# %%
def missing_values_table(df):
  mis_val = df.isnull().sum()
  mis_val_percent = 100*df.isnull().sum() / len(df)
  mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
  mis_val_table_ren_columns = mis_val_table.rename(columns = {0:'Missing Values' , 1:'of Total Values %'})
  return mis_val_table_ren_columns.round(2)

# %%
print("Missing In Police Data BEFORE :- ")
missing_values_table(police).style.background_gradient(cmap='Blues')
# Out:
# Missing In Police Data BEFORE :-
# <style type="text/css">
# #T_db33a_row0_col0, #T_db33a_row0_col1, #T_db33a_row1_col0, #T_db33a_row1_col1, #T_db33a_row8_col0, #T_db33a_row8_col1, #T_db33a_row13_col0, #T_db33a_row13_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_db33a_row2_col0, #T_db33a_row2_col1, #T_db33a_row3_col0, #T_db33a_row3_col1, #T_db33a_row5_col0, #T_db33a_row5_col1, #T_db33a_row6_col0, #T_db33a_row6_col1, #T_db33a_row7_col0, #T_db33a_row7_col1, #T_db33a_row10_col0, #T_db33a_row10_col1, #T_db33a_row11_col0, #T_db33a_row11_col1, #T_db33a_row12_col0, #T_db33a_row12_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_db33a_row4_col0, #T_db33a_row4_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_db33a_row9_col0, #T_db33a_row9_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_db33a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# - #### <span style="color:#08306B;"> From the previous table `'search_type'` Column has more than `50% null values`, So let's `drop` it. </span>

# %%
police.drop('search_type', axis=1 , inplace=True)

# %% [markdown]
# - #### <span style="color:#08306B;">  There are about `5123` Nan rows, So let's `drop` it.</span>

# %%
police.dropna(subset = ['driver_race'], inplace=True)

# %%
print("Missing In Police Data :- ")
missing_values_table(police).style.background_gradient(cmap='Blues')
# Out:
# Missing In Police Data :-
# <style type="text/css">
# #T_fb745_row0_col0, #T_fb745_row0_col1, #T_fb745_row1_col0, #T_fb745_row1_col1, #T_fb745_row2_col1, #T_fb745_row3_col0, #T_fb745_row3_col1, #T_fb745_row5_col0, #T_fb745_row5_col1, #T_fb745_row6_col0, #T_fb745_row6_col1, #T_fb745_row7_col0, #T_fb745_row7_col1, #T_fb745_row8_col0, #T_fb745_row8_col1, #T_fb745_row9_col0, #T_fb745_row9_col1, #T_fb745_row10_col0, #T_fb745_row10_col1, #T_fb745_row11_col0, #T_fb745_row11_col1, #T_fb745_row12_col0, #T_fb745_row12_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fb745_row2_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_fb745_row4_col0, #T_fb745_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fb745">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb745_level0_col0" class="col_heading level0 col0" >Missing Values</th>
# ...

# %% [markdown]
# - #### <span style="color:#08306B;">  `'driver_age'` and `'driver_gender'` columns also have null values, So how we can deal with them. </span>

# %%
police['driver_age'].unique()
# Out:
# array([20., 40., 33., 19., 21., 23., 36., 35., 26., 39., 50., 47., 52.,
#        38., 41., 28., 46., 32., 58., 27., 43., 24., 17., 22., 44., 48.,
#        34., 55., 51., 45., 29., 31., 37., 67., 25., 42., 30., 18., 57.,
#        49., 61., 70., nan, 53., 60., 59., 64., 63., 54., 56., 66., 62.,
#        69., 81., 68., 76., 75., 74., 82., 65., 72., 16., 77., 73., 71.,
#        80., 79., 78., 88., 15., 83., 86., 84., 85., 87., 99., 89., 94.,
#        90.])

# %%
mean_age = police['driver_age'].mean()

# %%
police['driver_age'] = police['driver_age'].fillna(mean_age)

# %%
police['driver_gender'].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
police.dropna(subset = ['driver_gender','driver_age_raw'], inplace=True)

# %%
print("Missing In Police Data After :- ")
missing_values_table(police).style.background_gradient(cmap='Blues')
# Out:
# Missing In Police Data After :-
# <style type="text/css">
# #T_c0284_row0_col0, #T_c0284_row0_col1, #T_c0284_row1_col0, #T_c0284_row1_col1, #T_c0284_row2_col0, #T_c0284_row2_col1, #T_c0284_row3_col0, #T_c0284_row3_col1, #T_c0284_row4_col0, #T_c0284_row4_col1, #T_c0284_row5_col0, #T_c0284_row5_col1, #T_c0284_row6_col0, #T_c0284_row6_col1, #T_c0284_row7_col0, #T_c0284_row7_col1, #T_c0284_row8_col0, #T_c0284_row8_col1, #T_c0284_row9_col0, #T_c0284_row9_col1, #T_c0284_row10_col0, #T_c0284_row10_col1, #T_c0284_row11_col0, #T_c0284_row11_col1, #T_c0284_row12_col0, #T_c0284_row12_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_c0284">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0284_level0_col0" class="col_heading level0 col0" >Missing Values</th>
#       <th id="T_c0284_level0_col1" class="col_heading level0 col1" >of Total Values %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# - #### <span style="color:#08306B;">  Now our data is free of missing values `:)` </span>

# %%
police.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_345c7_row0_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_345c7_row0_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_345c7_row1_col3, #T_345c7_row3_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_345c7_row1_col4, #T_345c7_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_345c7_row2_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_345c7_row2_col4 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_345c7_row4_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_345c7_row4_col4 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_345c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_345c7_level0_col0" class="col_heading level0 col0" >stop_date</th>
#       <th id="T_345c7_level0_col1" class="col_heading level0 col1" >stop_time</th>
# ...

# %%
police.insert(1,'stop_year',0)
police['stop_year'] = police['stop_date'].str[:4]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7232\1900554686.py in <module>
# ----> 1 police.insert(1,'stop_year',0)
#       2 police['stop_year'] = police['stop_date'].str[:4]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4441         if not allow_duplicates and column in self.columns:
#    4442             # Should this be a different kind of error??
# -> 4443             raise ValueError(f"cannot insert {column}, already exists")
#    4444         if not isinstance(loc, int):
#    4445             raise TypeError("loc must be int")
#
# ValueError: cannot insert stop_year, already exists

# %%
police.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_7486a_row0_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_7486a_row0_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_7486a_row1_col3, #T_7486a_row3_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7486a_row1_col4, #T_7486a_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7486a_row2_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_7486a_row2_col4 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_7486a_row4_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_7486a_row4_col4 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_7486a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7486a_level0_col0" class="col_heading level0 col0" >stop_date</th>
#       <th id="T_7486a_level0_col1" class="col_heading level0 col1" >stop_time</th>
# ...
