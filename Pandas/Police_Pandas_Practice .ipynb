# %% [markdown]
# <a class="anchor" id="About_Data"></a>
# # <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 20px 20px;overflow:hidden;font-weight:500">Police 🚨👮‍♀</p>

# %% [markdown]
# <img src="https://media0.giphy.com/media/G825ArmDSn6Ue5g152/giphy.gif?cid=6c09b952m7vzpzgzjpmdnsq601p0jwqqiksohe8x8tzgbl0f&ep=v1_internal_gif_by_id&rid=giphy.gif&ct=g" width="100%" height="100%">

# %% [markdown]
# <a class="anchor" id="About_Data"></a>
# # <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Introduction  🚓</p>

# %% [markdown]
# <div style = 'border : 5px solid #0c4da3; background-color:lightred;padding:10px'>
#
# This project uses `Python's Pandas library` to clean and analyze
# [Police traffic Dataset](https://www.kaggle.com/datasets/melihkanbay/police/data).
#
# The goal is to `practice data analysis` by identifying and fixing issues like missing values and inconsistencies in the dataset.

# %% [markdown]
# <a class="anchor" id="Cleaning_Data"></a>
# # <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 15px;overflow:hidden;font-weight:500">Data Cleaning  🔍🛠</p>

# %%
import pandas as pd
import warnings
warnings.simplefilter("ignore")

# %%
police = pd.read_csv("police.csv")

# %%
police.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_740ee_row0_col2, #T_740ee_row1_col2, #T_740ee_row2_col2, #T_740ee_row3_col2, #T_740ee_row4_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_740ee_row0_col4 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_740ee_row0_col5 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_740ee_row1_col4, #T_740ee_row3_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_740ee_row1_col5, #T_740ee_row3_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_740ee_row2_col4 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_740ee_row2_col5 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_740ee_row4_col4 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_740ee_row4_col5 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_740ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_740ee_level0_col0" class="col_heading level0 col0" >stop_date</th>
#       <th id="T_740ee_level0_col1" class="col_heading level0 col1" >stop_time</th>
#       <th id="T_740ee_level0_col2" class="col_heading level0 col2" >county_name</th>
#       <th id="T_740ee_level0_col3" class="col_heading level0 col3" >driver_gender</th>
#       <th id="T_740ee_level0_col4" class="col_heading level0 col4" >driver_age_raw</th>
#       <th id="T_740ee_level0_col5" class="col_heading level0 col5" >driver_age</th>
#       <th id="T_740ee_level0_col6" class="col_heading level0 col6" >driver_race</th>
#       <th id="T_740ee_level0_col7" class="col_heading level0 col7" >violation_raw</th>
#       <th id="T_740ee_level0_col8" class="col_heading level0 col8" >violation</th>
#       <th id="T_740ee_level0_col9" class="col_heading level0 col9" >search_conducted</th>
#       <th id="T_740ee_level0_col10" class="col_heading level0 col10" >search_type</th>
#       <th id="T_740ee_level0_col11" class="col_heading level0 col11" >stop_outcome</th>
#       <th id="T_740ee_level0_col12" class="col_heading level0 col12" >is_arrested</th>
#       <th id="T_740ee_level0_col13" class="col_heading level0 col13" >stop_duration</th>
#       <th id="T_740ee_level0_col14" class="col_heading level0 col14" >drugs_related_stop</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_740ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_740ee_row0_col0" class="data row0 col0" >2005-01-02</td>
#       <td id="T_740ee_row0_col1" class="data row0 col1" >01:55</td>
#       <td id="T_740ee_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_740ee_row0_col3" class="data row0 col3" >M</td>
#       <td id="T_740ee_row0_col4" class="data row0 col4" >1985.000000</td>
#       <td id="T_740ee_row0_col5" class="data row0 col5" >20.000000</td>
#       <td id="T_740ee_row0_col6" class="data row0 col6" >White</td>
#       <td id="T_740ee_row0_col7" class="data row0 col7" >Speeding</td>
#       <td id="T_740ee_row0_col8" class="data row0 col8" >Speeding</td>
#       <td id="T_740ee_row0_col9" class="data row0 col9" >False</td>
#       <td id="T_740ee_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_740ee_row0_col11" class="data row0 col11" >Citation</td>
#       <td id="T_740ee_row0_col12" class="data row0 col12" >False</td>
#       <td id="T_740ee_row0_col13" class="data row0 col13" >0-15 Min</td>
#       <td id="T_740ee_row0_col14" class="data row0 col14" >False</td>
#     </tr>
#     <tr>
#       <th id="T_740ee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_740ee_row1_col0" class="data row1 col0" >2005-01-18</td>
#       <td id="T_740ee_row1_col1" class="data row1 col1" >08:15</td>
#       <td id="T_740ee_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_740ee_row1_col3" class="data row1 col3" >M</td>
#       <td id="T_740ee_row1_col4" class="data row1 col4" >1965.000000</td>
#       <td id="T_740ee_row1_col5" class="data row1 col5" >40.000000</td>
#       <td id="T_740ee_row1_col6" class="data row1 col6" >White</td>
#       <td id="T_740ee_row1_col7" class="data row1 col7" >Speeding</td>
#       <td id="T_740ee_row1_col8" class="data row1 col8" >Speeding</td>
#       <td id="T_740ee_row1_col9" class="data row1 col9" >False</td>
#       <td id="T_740ee_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_740ee_row1_col11" class="data row1 col11" >Citation</td>
#       <td id="T_740ee_row1_col12" class="data row1 col12" >False</td>
#       <td id="T_740ee_row1_col13" class="data row1 col13" >0-15 Min</td>
#       <td id="T_740ee_row1_col14" class="data row1 col14" >False</td>
#     </tr>
#     <tr>
#       <th id="T_740ee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_740ee_row2_col0" class="data row2 col0" >2005-01-23</td>
#       <td id="T_740ee_row2_col1" class="data row2 col1" >23:15</td>
#       <td id="T_740ee_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_740ee_row2_col3" class="data row2 col3" >M</td>
#       <td id="T_740ee_row2_col4" class="data row2 col4" >1972.000000</td>
#       <td id="T_740ee_row2_col5" class="data row2 col5" >33.000000</td>
#       <td id="T_740ee_row2_col6" class="data row2 col6" >White</td>
#       <td id="T_740ee_row2_col7" class="data row2 col7" >Speeding</td>
#       <td id="T_740ee_row2_col8" class="data row2 col8" >Speeding</td>
#       <td id="T_740ee_row2_col9" class="data row2 col9" >False</td>
#       <td id="T_740ee_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_740ee_row2_col11" class="data row2 col11" >Citation</td>
#       <td id="T_740ee_row2_col12" class="data row2 col12" >False</td>
#       <td id="T_740ee_row2_col13" class="data row2 col13" >0-15 Min</td>
#       <td id="T_740ee_row2_col14" class="data row2 col14" >False</td>
#     </tr>
#     <tr>
#       <th id="T_740ee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_740ee_row3_col0" class="data row3 col0" >2005-02-20</td>
#       <td id="T_740ee_row3_col1" class="data row3 col1" >17:15</td>
#       <td id="T_740ee_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_740ee_row3_col3" class="data row3 col3" >M</td>
#       <td id="T_740ee_row3_col4" class="data row3 col4" >1986.000000</td>
#       <td id="T_740ee_row3_col5" class="data row3 col5" >19.000000</td>
#       <td id="T_740ee_row3_col6" class="data row3 col6" >White</td>
#       <td id="T_740ee_row3_col7" class="data row3 col7" >Call for Service</td>
#       <td id="T_740ee_row3_col8" class="data row3 col8" >Other</td>
#       <td id="T_740ee_row3_col9" class="data row3 col9" >False</td>
#       <td id="T_740ee_row3_col10" class="data row3 col10" >nan</td>
#       <td id="T_740ee_row3_col11" class="data row3 col11" >Arrest Driver</td>
#       <td id="T_740ee_row3_col12" class="data row3 col12" >True</td>
#       <td id="T_740ee_row3_col13" class="data row3 col13" >16-30 Min</td>
#       <td id="T_740ee_row3_col14" class="data row3 col14" >False</td>
#     </tr>
#     <tr>
#       <th id="T_740ee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_740ee_row4_col0" class="data row4 col0" >2005-03-14</td>
#       <td id="T_740ee_row4_col1" class="data row4 col1" >10:00</td>
#       <td id="T_740ee_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_740ee_row4_col3" class="data row4 col3" >F</td>
#       <td id="T_740ee_row4_col4" class="data row4 col4" >1984.000000</td>
#       <td id="T_740ee_row4_col5" class="data row4 col5" >21.000000</td>
#       <td id="T_740ee_row4_col6" class="data row4 col6" >White</td>
#       <td id="T_740ee_row4_col7" class="data row4 col7" >Speeding</td>
#       <td id="T_740ee_row4_col8" class="data row4 col8" >Speeding</td>
#       <td id="T_740ee_row4_col9" class="data row4 col9" >False</td>
#       <td id="T_740ee_row4_col10" class="data row4 col10" >nan</td>
#       <td id="T_740ee_row4_col11" class="data row4 col11" >Citation</td>
#       <td id="T_740ee_row4_col12" class="data row4 col12" >False</td>
#       <td id="T_740ee_row4_col13" class="data row4 col13" >0-15 Min</td>
#       <td id="T_740ee_row4_col14" class="data row4 col14" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
police.shape
# Out:
# (91741, 15)

# %%
police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   county_name         0 non-null      float64
#  3   driver_gender       86406 non-null  object
#  4   driver_age_raw      86414 non-null  float64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86408 non-null  object
#  7   violation_raw       86408 non-null  object
#  8   violation           86408 non-null  object
#  9   search_conducted    91741 non-null  bool
#  10  search_type         3196 non-null   object
#  11  stop_outcome        86408 non-null  object
#  12  is_arrested         86408 non-null  object
#  13  stop_duration       86408 non-null  object
#  14  drugs_related_stop  91741 non-null  bool
# dtypes: bool(2), float64(3), object(10)
# memory usage: 9.3+ MB

# %%
police.dtypes
# Out:
# stop_date              object
# stop_time              object
# county_name           float64
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# search_type            object
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %%
police.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
police.describe().style.background_gradient(cmap = "Blues")
# Out:
# <style type="text/css">
# #T_74455_row0_col0, #T_74455_row1_col0, #T_74455_row1_col2, #T_74455_row2_col0, #T_74455_row2_col1, #T_74455_row2_col2, #T_74455_row3_col0, #T_74455_row3_col1, #T_74455_row3_col2, #T_74455_row4_col0, #T_74455_row4_col2, #T_74455_row5_col0, #T_74455_row5_col2, #T_74455_row6_col0, #T_74455_row6_col2, #T_74455_row7_col0, #T_74455_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_74455_row0_col1, #T_74455_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_74455_row1_col1, #T_74455_row4_col1, #T_74455_row5_col1, #T_74455_row6_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_74455_row7_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# </style>
# <table id="T_74455">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74455_level0_col0" class="col_heading level0 col0" >county_name</th>
#       <th id="T_74455_level0_col1" class="col_heading level0 col1" >driver_age_raw</th>
#       <th id="T_74455_level0_col2" class="col_heading level0 col2" >driver_age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74455_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_74455_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_74455_row0_col1" class="data row0 col1" >86414.000000</td>
#       <td id="T_74455_row0_col2" class="data row0 col2" >86120.000000</td>
#     </tr>
#     <tr>
#       <th id="T_74455_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_74455_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_74455_row1_col1" class="data row1 col1" >1970.491228</td>
#       <td id="T_74455_row1_col2" class="data row1 col2" >34.011333</td>
#     </tr>
#     <tr>
#       <th id="T_74455_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_74455_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_74455_row2_col1" class="data row2 col1" >110.914909</td>
#       <td id="T_74455_row2_col2" class="data row2 col2" >12.738564</td>
#     </tr>
#     <tr>
#       <th id="T_74455_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_74455_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_74455_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_74455_row3_col2" class="data row3 col2" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_74455_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_74455_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_74455_row4_col1" class="data row4 col1" >1967.000000</td>
#       <td id="T_74455_row4_col2" class="data row4 col2" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_74455_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_74455_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_74455_row5_col1" class="data row5 col1" >1980.000000</td>
#       <td id="T_74455_row5_col2" class="data row5 col2" >31.000000</td>
#     </tr>
#     <tr>
#       <th id="T_74455_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_74455_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_74455_row6_col1" class="data row6 col1" >1987.000000</td>
#       <td id="T_74455_row6_col2" class="data row6 col2" >43.000000</td>
#     </tr>
#     <tr>
#       <th id="T_74455_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_74455_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_74455_row7_col1" class="data row7 col1" >8801.000000</td>
#       <td id="T_74455_row7_col2" class="data row7 col2" >99.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
police.describe(include='O').T
# Out:
#                count unique                 top   freq
# stop_date      91741   3768          2012-01-11     69
# stop_time      91741   1436               11:00    323
# driver_gender  86406      2                   M  62895
# driver_race    86408      5               White  62158
# violation_raw  86408     12            Speeding  48463
# violation      86408      6            Speeding  48463
# search_type     3196     24  Incident to Arrest   1219
# stop_outcome   86408      6            Citation  77006
# is_arrested    86408      2               False  83479
# stop_duration  86408      5            0-15 Min  69543

# %% [markdown]
# <div style = 'border : 5px solid #0c4da3; background-color:lightred;padding:10px'>
#
# #### <u><span style="color:#08306B;">  Observation: </span></u>
#  - The police dataset consists of  `91741 rows` and `15 columns`.
#  - It has all `NAN` values in `"county_name"` column.
#  - There are some coloumns that have uncorrect data type.

# %%
police = police.drop(
    labels='county_name',
    axis=1)

# %%
police.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_c9c0b_row0_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_c9c0b_row0_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_c9c0b_row1_col3, #T_c9c0b_row3_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c9c0b_row1_col4, #T_c9c0b_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c9c0b_row2_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_c9c0b_row2_col4 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_c9c0b_row4_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_c9c0b_row4_col4 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_c9c0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9c0b_level0_col0" class="col_heading level0 col0" >stop_date</th>
#       <th id="T_c9c0b_level0_col1" class="col_heading level0 col1" >stop_time</th>
#       <th id="T_c9c0b_level0_col2" class="col_heading level0 col2" >driver_gender</th>
#       <th id="T_c9c0b_level0_col3" class="col_heading level0 col3" >driver_age_raw</th>
#       <th id="T_c9c0b_level0_col4" class="col_heading level0 col4" >driver_age</th>
#       <th id="T_c9c0b_level0_col5" class="col_heading level0 col5" >driver_race</th>
#       <th id="T_c9c0b_level0_col6" class="col_heading level0 col6" >violation_raw</th>
#       <th id="T_c9c0b_level0_col7" class="col_heading level0 col7" >violation</th>
#       <th id="T_c9c0b_level0_col8" class="col_heading level0 col8" >search_conducted</th>
#       <th id="T_c9c0b_level0_col9" class="col_heading level0 col9" >search_type</th>
#       <th id="T_c9c0b_level0_col10" class="col_heading level0 col10" >stop_outcome</th>
#       <th id="T_c9c0b_level0_col11" class="col_heading level0 col11" >is_arrested</th>
#       <th id="T_c9c0b_level0_col12" class="col_heading level0 col12" >stop_duration</th>
#       <th id="T_c9c0b_level0_col13" class="col_heading level0 col13" >drugs_related_stop</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9c0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9c0b_row0_col0" class="data row0 col0" >2005-01-02</td>
#       <td id="T_c9c0b_row0_col1" class="data row0 col1" >01:55</td>
#       <td id="T_c9c0b_row0_col2" class="data row0 col2" >M</td>
#       <td id="T_c9c0b_row0_col3" class="data row0 col3" >1985.000000</td>
#       <td id="T_c9c0b_row0_col4" class="data row0 col4" >20.000000</td>
#       <td id="T_c9c0b_row0_col5" class="data row0 col5" >White</td>
#       <td id="T_c9c0b_row0_col6" class="data row0 col6" >Speeding</td>
#       <td id="T_c9c0b_row0_col7" class="data row0 col7" >Speeding</td>
#       <td id="T_c9c0b_row0_col8" class="data row0 col8" >False</td>
#       <td id="T_c9c0b_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_c9c0b_row0_col10" class="data row0 col10" >Citation</td>
#       <td id="T_c9c0b_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_c9c0b_row0_col12" class="data row0 col12" >0-15 Min</td>
#       <td id="T_c9c0b_row0_col13" class="data row0 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c9c0b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c9c0b_row1_col0" class="data row1 col0" >2005-01-18</td>
#       <td id="T_c9c0b_row1_col1" class="data row1 col1" >08:15</td>
#       <td id="T_c9c0b_row1_col2" class="data row1 col2" >M</td>
#       <td id="T_c9c0b_row1_col3" class="data row1 col3" >1965.000000</td>
#       <td id="T_c9c0b_row1_col4" class="data row1 col4" >40.000000</td>
#       <td id="T_c9c0b_row1_col5" class="data row1 col5" >White</td>
#       <td id="T_c9c0b_row1_col6" class="data row1 col6" >Speeding</td>
#       <td id="T_c9c0b_row1_col7" class="data row1 col7" >Speeding</td>
#       <td id="T_c9c0b_row1_col8" class="data row1 col8" >False</td>
#       <td id="T_c9c0b_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_c9c0b_row1_col10" class="data row1 col10" >Citation</td>
#       <td id="T_c9c0b_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_c9c0b_row1_col12" class="data row1 col12" >0-15 Min</td>
#       <td id="T_c9c0b_row1_col13" class="data row1 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c9c0b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c9c0b_row2_col0" class="data row2 col0" >2005-01-23</td>
#       <td id="T_c9c0b_row2_col1" class="data row2 col1" >23:15</td>
#       <td id="T_c9c0b_row2_col2" class="data row2 col2" >M</td>
#       <td id="T_c9c0b_row2_col3" class="data row2 col3" >1972.000000</td>
#       <td id="T_c9c0b_row2_col4" class="data row2 col4" >33.000000</td>
#       <td id="T_c9c0b_row2_col5" class="data row2 col5" >White</td>
#       <td id="T_c9c0b_row2_col6" class="data row2 col6" >Speeding</td>
#       <td id="T_c9c0b_row2_col7" class="data row2 col7" >Speeding</td>
#       <td id="T_c9c0b_row2_col8" class="data row2 col8" >False</td>
#       <td id="T_c9c0b_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_c9c0b_row2_col10" class="data row2 col10" >Citation</td>
#       <td id="T_c9c0b_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_c9c0b_row2_col12" class="data row2 col12" >0-15 Min</td>
#       <td id="T_c9c0b_row2_col13" class="data row2 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c9c0b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c9c0b_row3_col0" class="data row3 col0" >2005-02-20</td>
#       <td id="T_c9c0b_row3_col1" class="data row3 col1" >17:15</td>
#       <td id="T_c9c0b_row3_col2" class="data row3 col2" >M</td>
#       <td id="T_c9c0b_row3_col3" class="data row3 col3" >1986.000000</td>
#       <td id="T_c9c0b_row3_col4" class="data row3 col4" >19.000000</td>
#       <td id="T_c9c0b_row3_col5" class="data row3 col5" >White</td>
#       <td id="T_c9c0b_row3_col6" class="data row3 col6" >Call for Service</td>
#       <td id="T_c9c0b_row3_col7" class="data row3 col7" >Other</td>
#       <td id="T_c9c0b_row3_col8" class="data row3 col8" >False</td>
#       <td id="T_c9c0b_row3_col9" class="data row3 col9" >nan</td>
#       <td id="T_c9c0b_row3_col10" class="data row3 col10" >Arrest Driver</td>
#       <td id="T_c9c0b_row3_col11" class="data row3 col11" >True</td>
#       <td id="T_c9c0b_row3_col12" class="data row3 col12" >16-30 Min</td>
#       <td id="T_c9c0b_row3_col13" class="data row3 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c9c0b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c9c0b_row4_col0" class="data row4 col0" >2005-03-14</td>
#       <td id="T_c9c0b_row4_col1" class="data row4 col1" >10:00</td>
#       <td id="T_c9c0b_row4_col2" class="data row4 col2" >F</td>
#       <td id="T_c9c0b_row4_col3" class="data row4 col3" >1984.000000</td>
#       <td id="T_c9c0b_row4_col4" class="data row4 col4" >21.000000</td>
#       <td id="T_c9c0b_row4_col5" class="data row4 col5" >White</td>
#       <td id="T_c9c0b_row4_col6" class="data row4 col6" >Speeding</td>
#       <td id="T_c9c0b_row4_col7" class="data row4 col7" >Speeding</td>
#       <td id="T_c9c0b_row4_col8" class="data row4 col8" >False</td>
#       <td id="T_c9c0b_row4_col9" class="data row4 col9" >nan</td>
#       <td id="T_c9c0b_row4_col10" class="data row4 col10" >Citation</td>
#       <td id="T_c9c0b_row4_col11" class="data row4 col11" >False</td>
#       <td id="T_c9c0b_row4_col12" class="data row4 col12" >0-15 Min</td>
#       <td id="T_c9c0b_row4_col13" class="data row4 col13" >False</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a class="anchor" id="Duplicated"></a>
# # <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:200">I. Duplicated Data 🔁</p>

# %%
police.duplicated().sum()
# Out:
# 479

# %% [markdown]
# - #### <span style="color:#08306B;">  There are about `479` duplicated rows, So let's `drop` it.</span>

# %%
police.drop_duplicates(inplace = True)

# %%
police.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_c1378_row0_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_c1378_row0_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_c1378_row1_col3, #T_c1378_row3_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c1378_row1_col4, #T_c1378_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c1378_row2_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_c1378_row2_col4 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_c1378_row4_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_c1378_row4_col4 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_c1378">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1378_level0_col0" class="col_heading level0 col0" >stop_date</th>
#       <th id="T_c1378_level0_col1" class="col_heading level0 col1" >stop_time</th>
#       <th id="T_c1378_level0_col2" class="col_heading level0 col2" >driver_gender</th>
#       <th id="T_c1378_level0_col3" class="col_heading level0 col3" >driver_age_raw</th>
#       <th id="T_c1378_level0_col4" class="col_heading level0 col4" >driver_age</th>
#       <th id="T_c1378_level0_col5" class="col_heading level0 col5" >driver_race</th>
#       <th id="T_c1378_level0_col6" class="col_heading level0 col6" >violation_raw</th>
#       <th id="T_c1378_level0_col7" class="col_heading level0 col7" >violation</th>
#       <th id="T_c1378_level0_col8" class="col_heading level0 col8" >search_conducted</th>
#       <th id="T_c1378_level0_col9" class="col_heading level0 col9" >search_type</th>
#       <th id="T_c1378_level0_col10" class="col_heading level0 col10" >stop_outcome</th>
#       <th id="T_c1378_level0_col11" class="col_heading level0 col11" >is_arrested</th>
#       <th id="T_c1378_level0_col12" class="col_heading level0 col12" >stop_duration</th>
#       <th id="T_c1378_level0_col13" class="col_heading level0 col13" >drugs_related_stop</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1378_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1378_row0_col0" class="data row0 col0" >2005-01-02</td>
#       <td id="T_c1378_row0_col1" class="data row0 col1" >01:55</td>
#       <td id="T_c1378_row0_col2" class="data row0 col2" >M</td>
#       <td id="T_c1378_row0_col3" class="data row0 col3" >1985.000000</td>
#       <td id="T_c1378_row0_col4" class="data row0 col4" >20.000000</td>
#       <td id="T_c1378_row0_col5" class="data row0 col5" >White</td>
#       <td id="T_c1378_row0_col6" class="data row0 col6" >Speeding</td>
#       <td id="T_c1378_row0_col7" class="data row0 col7" >Speeding</td>
#       <td id="T_c1378_row0_col8" class="data row0 col8" >False</td>
#       <td id="T_c1378_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_c1378_row0_col10" class="data row0 col10" >Citation</td>
#       <td id="T_c1378_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_c1378_row0_col12" class="data row0 col12" >0-15 Min</td>
#       <td id="T_c1378_row0_col13" class="data row0 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c1378_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c1378_row1_col0" class="data row1 col0" >2005-01-18</td>
#       <td id="T_c1378_row1_col1" class="data row1 col1" >08:15</td>
#       <td id="T_c1378_row1_col2" class="data row1 col2" >M</td>
#       <td id="T_c1378_row1_col3" class="data row1 col3" >1965.000000</td>
#       <td id="T_c1378_row1_col4" class="data row1 col4" >40.000000</td>
#       <td id="T_c1378_row1_col5" class="data row1 col5" >White</td>
#       <td id="T_c1378_row1_col6" class="data row1 col6" >Speeding</td>
#       <td id="T_c1378_row1_col7" class="data row1 col7" >Speeding</td>
#       <td id="T_c1378_row1_col8" class="data row1 col8" >False</td>
#       <td id="T_c1378_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_c1378_row1_col10" class="data row1 col10" >Citation</td>
#       <td id="T_c1378_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_c1378_row1_col12" class="data row1 col12" >0-15 Min</td>
#       <td id="T_c1378_row1_col13" class="data row1 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c1378_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c1378_row2_col0" class="data row2 col0" >2005-01-23</td>
#       <td id="T_c1378_row2_col1" class="data row2 col1" >23:15</td>
#       <td id="T_c1378_row2_col2" class="data row2 col2" >M</td>
#       <td id="T_c1378_row2_col3" class="data row2 col3" >1972.000000</td>
#       <td id="T_c1378_row2_col4" class="data row2 col4" >33.000000</td>
#       <td id="T_c1378_row2_col5" class="data row2 col5" >White</td>
#       <td id="T_c1378_row2_col6" class="data row2 col6" >Speeding</td>
#       <td id="T_c1378_row2_col7" class="data row2 col7" >Speeding</td>
#       <td id="T_c1378_row2_col8" class="data row2 col8" >False</td>
#       <td id="T_c1378_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_c1378_row2_col10" class="data row2 col10" >Citation</td>
#       <td id="T_c1378_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_c1378_row2_col12" class="data row2 col12" >0-15 Min</td>
#       <td id="T_c1378_row2_col13" class="data row2 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c1378_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c1378_row3_col0" class="data row3 col0" >2005-02-20</td>
#       <td id="T_c1378_row3_col1" class="data row3 col1" >17:15</td>
#       <td id="T_c1378_row3_col2" class="data row3 col2" >M</td>
#       <td id="T_c1378_row3_col3" class="data row3 col3" >1986.000000</td>
#       <td id="T_c1378_row3_col4" class="data row3 col4" >19.000000</td>
#       <td id="T_c1378_row3_col5" class="data row3 col5" >White</td>
#       <td id="T_c1378_row3_col6" class="data row3 col6" >Call for Service</td>
#       <td id="T_c1378_row3_col7" class="data row3 col7" >Other</td>
#       <td id="T_c1378_row3_col8" class="data row3 col8" >False</td>
#       <td id="T_c1378_row3_col9" class="data row3 col9" >nan</td>
#       <td id="T_c1378_row3_col10" class="data row3 col10" >Arrest Driver</td>
#       <td id="T_c1378_row3_col11" class="data row3 col11" >True</td>
#       <td id="T_c1378_row3_col12" class="data row3 col12" >16-30 Min</td>
#       <td id="T_c1378_row3_col13" class="data row3 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c1378_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c1378_row4_col0" class="data row4 col0" >2005-03-14</td>
#       <td id="T_c1378_row4_col1" class="data row4 col1" >10:00</td>
#       <td id="T_c1378_row4_col2" class="data row4 col2" >F</td>
#       <td id="T_c1378_row4_col3" class="data row4 col3" >1984.000000</td>
#       <td id="T_c1378_row4_col4" class="data row4 col4" >21.000000</td>
#       <td id="T_c1378_row4_col5" class="data row4 col5" >White</td>
#       <td id="T_c1378_row4_col6" class="data row4 col6" >Speeding</td>
#       <td id="T_c1378_row4_col7" class="data row4 col7" >Speeding</td>
#       <td id="T_c1378_row4_col8" class="data row4 col8" >False</td>
#       <td id="T_c1378_row4_col9" class="data row4 col9" >nan</td>
#       <td id="T_c1378_row4_col10" class="data row4 col10" >Citation</td>
#       <td id="T_c1378_row4_col11" class="data row4 col11" >False</td>
#       <td id="T_c1378_row4_col12" class="data row4 col12" >0-15 Min</td>
#       <td id="T_c1378_row4_col13" class="data row4 col13" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
police.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <a class="anchor" id="Missing"></a>
# # <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:200">II. Missing Data ❔❔</p>

# %%
def missing_values_table(df):
  mis_val = df.isnull().sum()
  mis_val_percent = 100*df.isnull().sum() / len(df)
  mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
  mis_val_table_ren_columns = mis_val_table.rename(columns = {0:'Missing Values' , 1:'of Total Values %'})
  return mis_val_table_ren_columns.round(2)

# %%
print("Missing In Police Data BEFORE :- ")
missing_values_table(police).style.background_gradient(cmap='Blues')
# Out:
# Missing In Police Data BEFORE :-
# <style type="text/css">
# #T_f0caf_row0_col0, #T_f0caf_row0_col1, #T_f0caf_row1_col0, #T_f0caf_row1_col1, #T_f0caf_row8_col0, #T_f0caf_row8_col1, #T_f0caf_row13_col0, #T_f0caf_row13_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f0caf_row2_col0, #T_f0caf_row2_col1, #T_f0caf_row3_col0, #T_f0caf_row3_col1, #T_f0caf_row5_col0, #T_f0caf_row5_col1, #T_f0caf_row6_col0, #T_f0caf_row6_col1, #T_f0caf_row7_col0, #T_f0caf_row7_col1, #T_f0caf_row10_col0, #T_f0caf_row10_col1, #T_f0caf_row11_col0, #T_f0caf_row11_col1, #T_f0caf_row12_col0, #T_f0caf_row12_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_f0caf_row4_col0, #T_f0caf_row4_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_f0caf_row9_col0, #T_f0caf_row9_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f0caf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0caf_level0_col0" class="col_heading level0 col0" >Missing Values</th>
#       <th id="T_f0caf_level0_col1" class="col_heading level0 col1" >of Total Values %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0caf_level0_row0" class="row_heading level0 row0" >stop_date</th>
#       <td id="T_f0caf_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_f0caf_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f0caf_level0_row1" class="row_heading level0 row1" >stop_time</th>
#       <td id="T_f0caf_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_f0caf_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f0caf_level0_row2" class="row_heading level0 row2" >driver_gender</th>
#       <td id="T_f0caf_row2_col0" class="data row2 col0" >5125</td>
#       <td id="T_f0caf_row2_col1" class="data row2 col1" >5.620000</td>
#     </tr>
#     <tr>
#       <th id="T_f0caf_level0_row3" class="row_heading level0 row3" >driver_age_raw</th>
#       <td id="T_f0caf_row3_col0" class="data row3 col0" >5117</td>
#       <td id="T_f0caf_row3_col1" class="data row3 col1" >5.610000</td>
#     </tr>
#     <tr>
#       <th id="T_f0caf_level0_row4" class="row_heading level0 row4" >driver_age</th>
#       <td id="T_f0caf_row4_col0" class="data row4 col0" >5410</td>
#       <td id="T_f0caf_row4_col1" class="data row4 col1" >5.930000</td>
#     </tr>
#     <tr>
#       <th id="T_f0caf_level0_row5" class="row_heading level0 row5" >driver_race</th>
#       <td id="T_f0caf_row5_col0" class="data row5 col0" >5123</td>
#       <td id="T_f0caf_row5_col1" class="data row5 col1" >5.610000</td>
#     </tr>
#     <tr>
#       <th id="T_f0caf_level0_row6" class="row_heading level0 row6" >violation_raw</th>
#       <td id="T_f0caf_row6_col0" class="data row6 col0" >5123</td>
#       <td id="T_f0caf_row6_col1" class="data row6 col1" >5.610000</td>
#     </tr>
#     <tr>
#       <th id="T_f0caf_level0_row7" class="row_heading level0 row7" >violation</th>
#       <td id="T_f0caf_row7_col0" class="data row7 col0" >5123</td>
#       <td id="T_f0caf_row7_col1" class="data row7 col1" >5.610000</td>
#     </tr>
#     <tr>
#       <th id="T_f0caf_level0_row8" class="row_heading level0 row8" >search_conducted</th>
#       <td id="T_f0caf_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_f0caf_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f0caf_level0_row9" class="row_heading level0 row9" >search_type</th>
#       <td id="T_f0caf_row9_col0" class="data row9 col0" >88075</td>
#       <td id="T_f0caf_row9_col1" class="data row9 col1" >96.510000</td>
#     </tr>
#     <tr>
#       <th id="T_f0caf_level0_row10" class="row_heading level0 row10" >stop_outcome</th>
#       <td id="T_f0caf_row10_col0" class="data row10 col0" >5123</td>
#       <td id="T_f0caf_row10_col1" class="data row10 col1" >5.610000</td>
#     </tr>
#     <tr>
#       <th id="T_f0caf_level0_row11" class="row_heading level0 row11" >is_arrested</th>
#       <td id="T_f0caf_row11_col0" class="data row11 col0" >5123</td>
#       <td id="T_f0caf_row11_col1" class="data row11 col1" >5.610000</td>
#     </tr>
#     <tr>
#       <th id="T_f0caf_level0_row12" class="row_heading level0 row12" >stop_duration</th>
#       <td id="T_f0caf_row12_col0" class="data row12 col0" >5123</td>
#       <td id="T_f0caf_row12_col1" class="data row12 col1" >5.610000</td>
#     </tr>
#     <tr>
#       <th id="T_f0caf_level0_row13" class="row_heading level0 row13" >drugs_related_stop</th>
#       <td id="T_f0caf_row13_col0" class="data row13 col0" >0</td>
#       <td id="T_f0caf_row13_col1" class="data row13 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - #### <span style="color:#08306B;"> From the previous table `'search_type'` Column has more than `50% null values`, So let's `drop` it. </span>

# %%
police.drop('search_type', axis=1 , inplace=True)

# %% [markdown]
# - #### <span style="color:#08306B;">  There are about `5123` Nan rows, So let's `drop` it.</span>

# %%
police.dropna(subset = ['driver_race'], inplace=True)

# %%
print("Missing In Police Data :- ")
missing_values_table(police).style.background_gradient(cmap='Blues')
# Out:
# Missing In Police Data :-
# <style type="text/css">
# #T_e164a_row0_col0, #T_e164a_row0_col1, #T_e164a_row1_col0, #T_e164a_row1_col1, #T_e164a_row2_col1, #T_e164a_row3_col0, #T_e164a_row3_col1, #T_e164a_row5_col0, #T_e164a_row5_col1, #T_e164a_row6_col0, #T_e164a_row6_col1, #T_e164a_row7_col0, #T_e164a_row7_col1, #T_e164a_row8_col0, #T_e164a_row8_col1, #T_e164a_row9_col0, #T_e164a_row9_col1, #T_e164a_row10_col0, #T_e164a_row10_col1, #T_e164a_row11_col0, #T_e164a_row11_col1, #T_e164a_row12_col0, #T_e164a_row12_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e164a_row2_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_e164a_row4_col0, #T_e164a_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e164a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e164a_level0_col0" class="col_heading level0 col0" >Missing Values</th>
#       <th id="T_e164a_level0_col1" class="col_heading level0 col1" >of Total Values %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e164a_level0_row0" class="row_heading level0 row0" >stop_date</th>
#       <td id="T_e164a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_e164a_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e164a_level0_row1" class="row_heading level0 row1" >stop_time</th>
#       <td id="T_e164a_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_e164a_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e164a_level0_row2" class="row_heading level0 row2" >driver_gender</th>
#       <td id="T_e164a_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_e164a_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e164a_level0_row3" class="row_heading level0 row3" >driver_age_raw</th>
#       <td id="T_e164a_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_e164a_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e164a_level0_row4" class="row_heading level0 row4" >driver_age</th>
#       <td id="T_e164a_row4_col0" class="data row4 col0" >292</td>
#       <td id="T_e164a_row4_col1" class="data row4 col1" >0.340000</td>
#     </tr>
#     <tr>
#       <th id="T_e164a_level0_row5" class="row_heading level0 row5" >driver_race</th>
#       <td id="T_e164a_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_e164a_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e164a_level0_row6" class="row_heading level0 row6" >violation_raw</th>
#       <td id="T_e164a_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_e164a_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e164a_level0_row7" class="row_heading level0 row7" >violation</th>
#       <td id="T_e164a_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_e164a_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e164a_level0_row8" class="row_heading level0 row8" >search_conducted</th>
#       <td id="T_e164a_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_e164a_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e164a_level0_row9" class="row_heading level0 row9" >stop_outcome</th>
#       <td id="T_e164a_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_e164a_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e164a_level0_row10" class="row_heading level0 row10" >is_arrested</th>
#       <td id="T_e164a_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_e164a_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e164a_level0_row11" class="row_heading level0 row11" >stop_duration</th>
#       <td id="T_e164a_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_e164a_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e164a_level0_row12" class="row_heading level0 row12" >drugs_related_stop</th>
#       <td id="T_e164a_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_e164a_row12_col1" class="data row12 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - #### <span style="color:#08306B;">  `'driver_age'` and `'driver_gender'` columns also have null values, So how we can deal with them. </span>

# %%
police['driver_age'].unique()
# Out:
# array([20., 40., 33., 19., 21., 23., 36., 35., 26., 39., 50., 47., 52.,
#        38., 41., 28., 46., 32., 58., 27., 43., 24., 17., 22., 44., 48.,
#        34., 55., 51., 45., 29., 31., 37., 67., 25., 42., 30., 18., 57.,
#        49., 61., 70., nan, 53., 60., 59., 64., 63., 54., 56., 66., 62.,
#        69., 81., 68., 76., 75., 74., 82., 65., 72., 16., 77., 73., 71.,
#        80., 79., 78., 88., 15., 83., 86., 84., 85., 87., 99., 89., 94.,
#        90.])

# %%
mean_age = police['driver_age'].mean()

# %%
police['driver_age'] = police['driver_age'].fillna(mean_age)

# %%
police['driver_gender'].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
police.dropna(subset = ['driver_gender','driver_age_raw'], inplace=True)

# %%
print("Missing In Police Data After :- ")
missing_values_table(police).style.background_gradient(cmap='Blues')
# Out:
# Missing In Police Data After :-
# <style type="text/css">
# #T_a3d59_row0_col0, #T_a3d59_row0_col1, #T_a3d59_row1_col0, #T_a3d59_row1_col1, #T_a3d59_row2_col0, #T_a3d59_row2_col1, #T_a3d59_row3_col0, #T_a3d59_row3_col1, #T_a3d59_row4_col0, #T_a3d59_row4_col1, #T_a3d59_row5_col0, #T_a3d59_row5_col1, #T_a3d59_row6_col0, #T_a3d59_row6_col1, #T_a3d59_row7_col0, #T_a3d59_row7_col1, #T_a3d59_row8_col0, #T_a3d59_row8_col1, #T_a3d59_row9_col0, #T_a3d59_row9_col1, #T_a3d59_row10_col0, #T_a3d59_row10_col1, #T_a3d59_row11_col0, #T_a3d59_row11_col1, #T_a3d59_row12_col0, #T_a3d59_row12_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_a3d59">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3d59_level0_col0" class="col_heading level0 col0" >Missing Values</th>
#       <th id="T_a3d59_level0_col1" class="col_heading level0 col1" >of Total Values %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3d59_level0_row0" class="row_heading level0 row0" >stop_date</th>
#       <td id="T_a3d59_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a3d59_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3d59_level0_row1" class="row_heading level0 row1" >stop_time</th>
#       <td id="T_a3d59_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_a3d59_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3d59_level0_row2" class="row_heading level0 row2" >driver_gender</th>
#       <td id="T_a3d59_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_a3d59_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3d59_level0_row3" class="row_heading level0 row3" >driver_age_raw</th>
#       <td id="T_a3d59_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_a3d59_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3d59_level0_row4" class="row_heading level0 row4" >driver_age</th>
#       <td id="T_a3d59_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_a3d59_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3d59_level0_row5" class="row_heading level0 row5" >driver_race</th>
#       <td id="T_a3d59_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_a3d59_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3d59_level0_row6" class="row_heading level0 row6" >violation_raw</th>
#       <td id="T_a3d59_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_a3d59_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3d59_level0_row7" class="row_heading level0 row7" >violation</th>
#       <td id="T_a3d59_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_a3d59_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3d59_level0_row8" class="row_heading level0 row8" >search_conducted</th>
#       <td id="T_a3d59_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_a3d59_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3d59_level0_row9" class="row_heading level0 row9" >stop_outcome</th>
#       <td id="T_a3d59_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_a3d59_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3d59_level0_row10" class="row_heading level0 row10" >is_arrested</th>
#       <td id="T_a3d59_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_a3d59_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3d59_level0_row11" class="row_heading level0 row11" >stop_duration</th>
#       <td id="T_a3d59_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_a3d59_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3d59_level0_row12" class="row_heading level0 row12" >drugs_related_stop</th>
#       <td id="T_a3d59_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_a3d59_row12_col1" class="data row12 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - #### <span style="color:#08306B;">  Now our data is free of missing values `:)` </span>

# %%
police.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_4144c_row0_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_4144c_row0_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_4144c_row1_col3, #T_4144c_row3_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4144c_row1_col4, #T_4144c_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4144c_row2_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_4144c_row2_col4 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_4144c_row4_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_4144c_row4_col4 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_4144c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4144c_level0_col0" class="col_heading level0 col0" >stop_date</th>
#       <th id="T_4144c_level0_col1" class="col_heading level0 col1" >stop_time</th>
#       <th id="T_4144c_level0_col2" class="col_heading level0 col2" >driver_gender</th>
#       <th id="T_4144c_level0_col3" class="col_heading level0 col3" >driver_age_raw</th>
#       <th id="T_4144c_level0_col4" class="col_heading level0 col4" >driver_age</th>
#       <th id="T_4144c_level0_col5" class="col_heading level0 col5" >driver_race</th>
#       <th id="T_4144c_level0_col6" class="col_heading level0 col6" >violation_raw</th>
#       <th id="T_4144c_level0_col7" class="col_heading level0 col7" >violation</th>
#       <th id="T_4144c_level0_col8" class="col_heading level0 col8" >search_conducted</th>
#       <th id="T_4144c_level0_col9" class="col_heading level0 col9" >stop_outcome</th>
#       <th id="T_4144c_level0_col10" class="col_heading level0 col10" >is_arrested</th>
#       <th id="T_4144c_level0_col11" class="col_heading level0 col11" >stop_duration</th>
#       <th id="T_4144c_level0_col12" class="col_heading level0 col12" >drugs_related_stop</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4144c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4144c_row0_col0" class="data row0 col0" >2005-01-02</td>
#       <td id="T_4144c_row0_col1" class="data row0 col1" >01:55</td>
#       <td id="T_4144c_row0_col2" class="data row0 col2" >M</td>
#       <td id="T_4144c_row0_col3" class="data row0 col3" >1985.000000</td>
#       <td id="T_4144c_row0_col4" class="data row0 col4" >20.000000</td>
#       <td id="T_4144c_row0_col5" class="data row0 col5" >White</td>
#       <td id="T_4144c_row0_col6" class="data row0 col6" >Speeding</td>
#       <td id="T_4144c_row0_col7" class="data row0 col7" >Speeding</td>
#       <td id="T_4144c_row0_col8" class="data row0 col8" >False</td>
#       <td id="T_4144c_row0_col9" class="data row0 col9" >Citation</td>
#       <td id="T_4144c_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_4144c_row0_col11" class="data row0 col11" >0-15 Min</td>
#       <td id="T_4144c_row0_col12" class="data row0 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4144c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4144c_row1_col0" class="data row1 col0" >2005-01-18</td>
#       <td id="T_4144c_row1_col1" class="data row1 col1" >08:15</td>
#       <td id="T_4144c_row1_col2" class="data row1 col2" >M</td>
#       <td id="T_4144c_row1_col3" class="data row1 col3" >1965.000000</td>
#       <td id="T_4144c_row1_col4" class="data row1 col4" >40.000000</td>
#       <td id="T_4144c_row1_col5" class="data row1 col5" >White</td>
#       <td id="T_4144c_row1_col6" class="data row1 col6" >Speeding</td>
#       <td id="T_4144c_row1_col7" class="data row1 col7" >Speeding</td>
#       <td id="T_4144c_row1_col8" class="data row1 col8" >False</td>
#       <td id="T_4144c_row1_col9" class="data row1 col9" >Citation</td>
#       <td id="T_4144c_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_4144c_row1_col11" class="data row1 col11" >0-15 Min</td>
#       <td id="T_4144c_row1_col12" class="data row1 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4144c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4144c_row2_col0" class="data row2 col0" >2005-01-23</td>
#       <td id="T_4144c_row2_col1" class="data row2 col1" >23:15</td>
#       <td id="T_4144c_row2_col2" class="data row2 col2" >M</td>
#       <td id="T_4144c_row2_col3" class="data row2 col3" >1972.000000</td>
#       <td id="T_4144c_row2_col4" class="data row2 col4" >33.000000</td>
#       <td id="T_4144c_row2_col5" class="data row2 col5" >White</td>
#       <td id="T_4144c_row2_col6" class="data row2 col6" >Speeding</td>
#       <td id="T_4144c_row2_col7" class="data row2 col7" >Speeding</td>
#       <td id="T_4144c_row2_col8" class="data row2 col8" >False</td>
#       <td id="T_4144c_row2_col9" class="data row2 col9" >Citation</td>
#       <td id="T_4144c_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_4144c_row2_col11" class="data row2 col11" >0-15 Min</td>
#       <td id="T_4144c_row2_col12" class="data row2 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4144c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4144c_row3_col0" class="data row3 col0" >2005-02-20</td>
#       <td id="T_4144c_row3_col1" class="data row3 col1" >17:15</td>
#       <td id="T_4144c_row3_col2" class="data row3 col2" >M</td>
#       <td id="T_4144c_row3_col3" class="data row3 col3" >1986.000000</td>
#       <td id="T_4144c_row3_col4" class="data row3 col4" >19.000000</td>
#       <td id="T_4144c_row3_col5" class="data row3 col5" >White</td>
#       <td id="T_4144c_row3_col6" class="data row3 col6" >Call for Service</td>
#       <td id="T_4144c_row3_col7" class="data row3 col7" >Other</td>
#       <td id="T_4144c_row3_col8" class="data row3 col8" >False</td>
#       <td id="T_4144c_row3_col9" class="data row3 col9" >Arrest Driver</td>
#       <td id="T_4144c_row3_col10" class="data row3 col10" >True</td>
#       <td id="T_4144c_row3_col11" class="data row3 col11" >16-30 Min</td>
#       <td id="T_4144c_row3_col12" class="data row3 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4144c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4144c_row4_col0" class="data row4 col0" >2005-03-14</td>
#       <td id="T_4144c_row4_col1" class="data row4 col1" >10:00</td>
#       <td id="T_4144c_row4_col2" class="data row4 col2" >F</td>
#       <td id="T_4144c_row4_col3" class="data row4 col3" >1984.000000</td>
#       <td id="T_4144c_row4_col4" class="data row4 col4" >21.000000</td>
#       <td id="T_4144c_row4_col5" class="data row4 col5" >White</td>
#       <td id="T_4144c_row4_col6" class="data row4 col6" >Speeding</td>
#       <td id="T_4144c_row4_col7" class="data row4 col7" >Speeding</td>
#       <td id="T_4144c_row4_col8" class="data row4 col8" >False</td>
#       <td id="T_4144c_row4_col9" class="data row4 col9" >Citation</td>
#       <td id="T_4144c_row4_col10" class="data row4 col10" >False</td>
#       <td id="T_4144c_row4_col11" class="data row4 col11" >0-15 Min</td>
#       <td id="T_4144c_row4_col12" class="data row4 col12" >False</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a class="anchor" id="correction"></a>
# # <p style="padding:10px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:200">III. Data Correction ⚙️</p>

# %%
police.insert(1,'stop_year',0)
police['stop_year'] = police['stop_date'].str[:4]
police['stop_year'] = police['stop_year'].astype('int64')

# %%
police.insert(2,'stop_month',0)
police['stop_month'] = police['stop_date'].str[5:7]

# %%
police.insert(4,'stop_hour',0)

# %%
police['stop_hour'] = police['stop_time'].str[:2]
police['stop_hour'] = police['stop_hour'].astype('int64')

# %%
police.insert(5,'stop_daytime','')

# %%
police.loc[(police['stop_hour'] >= 6) & (police['stop_hour'] <= 11),'stop_daytime'] = 'Morning'
police.loc[(police['stop_hour'] >= 12) & (police['stop_hour'] <= 17),'stop_daytime'] = 'Afternoon'
police.loc[(police['stop_hour'] >= 18) & (police['stop_hour'] <= 21),'stop_daytime'] = 'Evening'
police.loc[(police['stop_hour'] >= 22) | (police['stop_hour'] <= 5),'stop_daytime'] = 'Night'

# %%
police.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_d620e_row0_col1, #T_d620e_row0_col4, #T_d620e_row1_col1, #T_d620e_row1_col7, #T_d620e_row2_col1, #T_d620e_row3_col1, #T_d620e_row3_col8, #T_d620e_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d620e_row0_col7 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_d620e_row0_col8 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_d620e_row1_col4 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_d620e_row1_col8, #T_d620e_row2_col4, #T_d620e_row3_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d620e_row2_col7 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_d620e_row2_col8 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_d620e_row3_col4 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_d620e_row4_col4 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_d620e_row4_col7 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_d620e_row4_col8 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_d620e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d620e_level0_col0" class="col_heading level0 col0" >stop_date</th>
#       <th id="T_d620e_level0_col1" class="col_heading level0 col1" >stop_year</th>
#       <th id="T_d620e_level0_col2" class="col_heading level0 col2" >stop_month</th>
#       <th id="T_d620e_level0_col3" class="col_heading level0 col3" >stop_time</th>
#       <th id="T_d620e_level0_col4" class="col_heading level0 col4" >stop_hour</th>
#       <th id="T_d620e_level0_col5" class="col_heading level0 col5" >stop_daytime</th>
#       <th id="T_d620e_level0_col6" class="col_heading level0 col6" >driver_gender</th>
#       <th id="T_d620e_level0_col7" class="col_heading level0 col7" >driver_age_raw</th>
#       <th id="T_d620e_level0_col8" class="col_heading level0 col8" >driver_age</th>
#       <th id="T_d620e_level0_col9" class="col_heading level0 col9" >driver_race</th>
#       <th id="T_d620e_level0_col10" class="col_heading level0 col10" >violation_raw</th>
#       <th id="T_d620e_level0_col11" class="col_heading level0 col11" >violation</th>
#       <th id="T_d620e_level0_col12" class="col_heading level0 col12" >search_conducted</th>
#       <th id="T_d620e_level0_col13" class="col_heading level0 col13" >stop_outcome</th>
#       <th id="T_d620e_level0_col14" class="col_heading level0 col14" >is_arrested</th>
#       <th id="T_d620e_level0_col15" class="col_heading level0 col15" >stop_duration</th>
#       <th id="T_d620e_level0_col16" class="col_heading level0 col16" >drugs_related_stop</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d620e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d620e_row0_col0" class="data row0 col0" >2005-01-02</td>
#       <td id="T_d620e_row0_col1" class="data row0 col1" >2005</td>
#       <td id="T_d620e_row0_col2" class="data row0 col2" >01</td>
#       <td id="T_d620e_row0_col3" class="data row0 col3" >01:55</td>
#       <td id="T_d620e_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_d620e_row0_col5" class="data row0 col5" >Night</td>
#       <td id="T_d620e_row0_col6" class="data row0 col6" >M</td>
#       <td id="T_d620e_row0_col7" class="data row0 col7" >1985.000000</td>
#       <td id="T_d620e_row0_col8" class="data row0 col8" >20.000000</td>
#       <td id="T_d620e_row0_col9" class="data row0 col9" >White</td>
#       <td id="T_d620e_row0_col10" class="data row0 col10" >Speeding</td>
#       <td id="T_d620e_row0_col11" class="data row0 col11" >Speeding</td>
#       <td id="T_d620e_row0_col12" class="data row0 col12" >False</td>
#       <td id="T_d620e_row0_col13" class="data row0 col13" >Citation</td>
#       <td id="T_d620e_row0_col14" class="data row0 col14" >False</td>
#       <td id="T_d620e_row0_col15" class="data row0 col15" >0-15 Min</td>
#       <td id="T_d620e_row0_col16" class="data row0 col16" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d620e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d620e_row1_col0" class="data row1 col0" >2005-01-18</td>
#       <td id="T_d620e_row1_col1" class="data row1 col1" >2005</td>
#       <td id="T_d620e_row1_col2" class="data row1 col2" >01</td>
#       <td id="T_d620e_row1_col3" class="data row1 col3" >08:15</td>
#       <td id="T_d620e_row1_col4" class="data row1 col4" >8</td>
#       <td id="T_d620e_row1_col5" class="data row1 col5" >Morning</td>
#       <td id="T_d620e_row1_col6" class="data row1 col6" >M</td>
#       <td id="T_d620e_row1_col7" class="data row1 col7" >1965.000000</td>
#       <td id="T_d620e_row1_col8" class="data row1 col8" >40.000000</td>
#       <td id="T_d620e_row1_col9" class="data row1 col9" >White</td>
#       <td id="T_d620e_row1_col10" class="data row1 col10" >Speeding</td>
#       <td id="T_d620e_row1_col11" class="data row1 col11" >Speeding</td>
#       <td id="T_d620e_row1_col12" class="data row1 col12" >False</td>
#       <td id="T_d620e_row1_col13" class="data row1 col13" >Citation</td>
#       <td id="T_d620e_row1_col14" class="data row1 col14" >False</td>
#       <td id="T_d620e_row1_col15" class="data row1 col15" >0-15 Min</td>
#       <td id="T_d620e_row1_col16" class="data row1 col16" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d620e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d620e_row2_col0" class="data row2 col0" >2005-01-23</td>
#       <td id="T_d620e_row2_col1" class="data row2 col1" >2005</td>
#       <td id="T_d620e_row2_col2" class="data row2 col2" >01</td>
#       <td id="T_d620e_row2_col3" class="data row2 col3" >23:15</td>
#       <td id="T_d620e_row2_col4" class="data row2 col4" >23</td>
#       <td id="T_d620e_row2_col5" class="data row2 col5" >Night</td>
#       <td id="T_d620e_row2_col6" class="data row2 col6" >M</td>
#       <td id="T_d620e_row2_col7" class="data row2 col7" >1972.000000</td>
#       <td id="T_d620e_row2_col8" class="data row2 col8" >33.000000</td>
#       <td id="T_d620e_row2_col9" class="data row2 col9" >White</td>
#       <td id="T_d620e_row2_col10" class="data row2 col10" >Speeding</td>
#       <td id="T_d620e_row2_col11" class="data row2 col11" >Speeding</td>
#       <td id="T_d620e_row2_col12" class="data row2 col12" >False</td>
#       <td id="T_d620e_row2_col13" class="data row2 col13" >Citation</td>
#       <td id="T_d620e_row2_col14" class="data row2 col14" >False</td>
#       <td id="T_d620e_row2_col15" class="data row2 col15" >0-15 Min</td>
#       <td id="T_d620e_row2_col16" class="data row2 col16" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d620e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d620e_row3_col0" class="data row3 col0" >2005-02-20</td>
#       <td id="T_d620e_row3_col1" class="data row3 col1" >2005</td>
#       <td id="T_d620e_row3_col2" class="data row3 col2" >02</td>
#       <td id="T_d620e_row3_col3" class="data row3 col3" >17:15</td>
#       <td id="T_d620e_row3_col4" class="data row3 col4" >17</td>
#       <td id="T_d620e_row3_col5" class="data row3 col5" >Afternoon</td>
#       <td id="T_d620e_row3_col6" class="data row3 col6" >M</td>
#       <td id="T_d620e_row3_col7" class="data row3 col7" >1986.000000</td>
#       <td id="T_d620e_row3_col8" class="data row3 col8" >19.000000</td>
#       <td id="T_d620e_row3_col9" class="data row3 col9" >White</td>
#       <td id="T_d620e_row3_col10" class="data row3 col10" >Call for Service</td>
#       <td id="T_d620e_row3_col11" class="data row3 col11" >Other</td>
#       <td id="T_d620e_row3_col12" class="data row3 col12" >False</td>
#       <td id="T_d620e_row3_col13" class="data row3 col13" >Arrest Driver</td>
#       <td id="T_d620e_row3_col14" class="data row3 col14" >True</td>
#       <td id="T_d620e_row3_col15" class="data row3 col15" >16-30 Min</td>
#       <td id="T_d620e_row3_col16" class="data row3 col16" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d620e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d620e_row4_col0" class="data row4 col0" >2005-03-14</td>
#       <td id="T_d620e_row4_col1" class="data row4 col1" >2005</td>
#       <td id="T_d620e_row4_col2" class="data row4 col2" >03</td>
#       <td

# %%
police = police.drop(labels=['stop_date','stop_time','driver_age_raw'],axis=1)

# %%
police.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_63e27_row0_col0, #T_63e27_row0_col2, #T_63e27_row1_col0, #T_63e27_row2_col0, #T_63e27_row3_col0, #T_63e27_row3_col5, #T_63e27_row4_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_63e27_row0_col5 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_63e27_row1_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_63e27_row1_col5, #T_63e27_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_63e27_row2_col5 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_63e27_row3_col2 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_63e27_row4_col2 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_63e27_row4_col5 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_63e27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63e27_level0_col0" class="col_heading level0 col0" >stop_year</th>
#       <th id="T_63e27_level0_col1" class="col_heading level0 col1" >stop_month</th>
#       <th id="T_63e27_level0_col2" class="col_heading level0 col2" >stop_hour</th>
#       <th id="T_63e27_level0_col3" class="col_heading level0 col3" >stop_daytime</th>
#       <th id="T_63e27_level0_col4" class="col_heading level0 col4" >driver_gender</th>
#       <th id="T_63e27_level0_col5" class="col_heading level0 col5" >driver_age</th>
#       <th id="T_63e27_level0_col6" class="col_heading level0 col6" >driver_race</th>
#       <th id="T_63e27_level0_col7" class="col_heading level0 col7" >violation_raw</th>
#       <th id="T_63e27_level0_col8" class="col_heading level0 col8" >violation</th>
#       <th id="T_63e27_level0_col9" class="col_heading level0 col9" >search_conducted</th>
#       <th id="T_63e27_level0_col10" class="col_heading level0 col10" >stop_outcome</th>
#       <th id="T_63e27_level0_col11" class="col_heading level0 col11" >is_arrested</th>
#       <th id="T_63e27_level0_col12" class="col_heading level0 col12" >stop_duration</th>
#       <th id="T_63e27_level0_col13" class="col_heading level0 col13" >drugs_related_stop</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63e27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63e27_row0_col0" class="data row0 col0" >2005</td>
#       <td id="T_63e27_row0_col1" class="data row0 col1" >01</td>
#       <td id="T_63e27_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_63e27_row0_col3" class="data row0 col3" >Night</td>
#       <td id="T_63e27_row0_col4" class="data row0 col4" >M</td>
#       <td id="T_63e27_row0_col5" class="data row0 col5" >20.000000</td>
#       <td id="T_63e27_row0_col6" class="data row0 col6" >White</td>
#       <td id="T_63e27_row0_col7" class="data row0 col7" >Speeding</td>
#       <td id="T_63e27_row0_col8" class="data row0 col8" >Speeding</td>
#       <td id="T_63e27_row0_col9" class="data row0 col9" >False</td>
#       <td id="T_63e27_row0_col10" class="data row0 col10" >Citation</td>
#       <td id="T_63e27_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_63e27_row0_col12" class="data row0 col12" >0-15 Min</td>
#       <td id="T_63e27_row0_col13" class="data row0 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_63e27_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_63e27_row1_col0" class="data row1 col0" >2005</td>
#       <td id="T_63e27_row1_col1" class="data row1 col1" >01</td>
#       <td id="T_63e27_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_63e27_row1_col3" class="data row1 col3" >Morning</td>
#       <td id="T_63e27_row1_col4" class="data row1 col4" >M</td>
#       <td id="T_63e27_row1_col5" class="data row1 col5" >40.000000</td>
#       <td id="T_63e27_row1_col6" class="data row1 col6" >White</td>
#       <td id="T_63e27_row1_col7" class="data row1 col7" >Speeding</td>
#       <td id="T_63e27_row1_col8" class="data row1 col8" >Speeding</td>
#       <td id="T_63e27_row1_col9" class="data row1 col9" >False</td>
#       <td id="T_63e27_row1_col10" class="data row1 col10" >Citation</td>
#       <td id="T_63e27_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_63e27_row1_col12" class="data row1 col12" >0-15 Min</td>
#       <td id="T_63e27_row1_col13" class="data row1 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_63e27_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_63e27_row2_col0" class="data row2 col0" >2005</td>
#       <td id="T_63e27_row2_col1" class="data row2 col1" >01</td>
#       <td id="T_63e27_row2_col2" class="data row2 col2" >23</td>
#       <td id="T_63e27_row2_col3" class="data row2 col3" >Night</td>
#       <td id="T_63e27_row2_col4" class="data row2 col4" >M</td>
#       <td id="T_63e27_row2_col5" class="data row2 col5" >33.000000</td>
#       <td id="T_63e27_row2_col6" class="data row2 col6" >White</td>
#       <td id="T_63e27_row2_col7" class="data row2 col7" >Speeding</td>
#       <td id="T_63e27_row2_col8" class="data row2 col8" >Speeding</td>
#       <td id="T_63e27_row2_col9" class="data row2 col9" >False</td>
#       <td id="T_63e27_row2_col10" class="data row2 col10" >Citation</td>
#       <td id="T_63e27_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_63e27_row2_col12" class="data row2 col12" >0-15 Min</td>
#       <td id="T_63e27_row2_col13" class="data row2 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_63e27_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_63e27_row3_col0" class="data row3 col0" >2005</td>
#       <td id="T_63e27_row3_col1" class="data row3 col1" >02</td>
#       <td id="T_63e27_row3_col2" class="data row3 col2" >17</td>
#       <td id="T_63e27_row3_col3" class="data row3 col3" >Afternoon</td>
#       <td id="T_63e27_row3_col4" class="data row3 col4" >M</td>
#       <td id="T_63e27_row3_col5" class="data row3 col5" >19.000000</td>
#       <td id="T_63e27_row3_col6" class="data row3 col6" >White</td>
#       <td id="T_63e27_row3_col7" class="data row3 col7" >Call for Service</td>
#       <td id="T_63e27_row3_col8" class="data row3 col8" >Other</td>
#       <td id="T_63e27_row3_col9" class="data row3 col9" >False</td>
#       <td id="T_63e27_row3_col10" class="data row3 col10" >Arrest Driver</td>
#       <td id="T_63e27_row3_col11" class="data row3 col11" >True</td>
#       <td id="T_63e27_row3_col12" class="data row3 col12" >16-30 Min</td>
#       <td id="T_63e27_row3_col13" class="data row3 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_63e27_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_63e27_row4_col0" class="data row4 col0" >2005</td>
#       <td id="T_63e27_row4_col1" class="data row4 col1" >03</td>
#       <td id="T_63e27_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_63e27_row4_col3" class="data row4 col3" >Morning</td>
#       <td id="T_63e27_row4_col4" class="data row4 col4" >F</td>
#       <td id="T_63e27_row4_col5" class="data row4 col5" >21.000000</td>
#       <td id="T_63e27_row4_col6" class="data row4 col6" >White</td>
#       <td id="T_63e27_row4_col7" class="data row4 col7" >Speeding</td>
#       <td id="T_63e27_row4_col8" class="data row4 col8" >Speeding</td>
#       <td id="T_63e27_row4_col9" class="data row4 col9" >False</td>
#       <td id="T_63e27_row4_col10" class="data row4 col10" >Citation</td>
#       <td id="T_63e27_row4_col11" class="data row4 col11" >False</td>
#       <td id="T_63e27_row4_col12" class="data row4 col12" >0-15 Min</td>
#       <td id="T_63e27_row4_col13" class="data row4 col13" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
police['driver_age'] = police['driver_age'].astype('int64')

# %%
police['stop_month'].unique()
# Out:
# array(['01', '02', '03', '04', '06', '07', '08', '09', '10', '11', '12',
#        '05'], dtype=object)

# %%
police['stop_month'] = police['stop_month'].replace({'01':'Jan' ,'02':'Feb' ,'03':'Mar', '04':'Apr','05':'May','06':'June','07':'July','08':'Aug','09':'Sept','10':'Oct','11':'Nov','12':'Dec'})

# %%
police['driver_gender'] = police['driver_gender'].replace({'M':'Male' ,'F':'Female'})

# %%
police.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_42dad_row0_col0, #T_42dad_row0_col2, #T_42dad_row1_col0, #T_42dad_row2_col0, #T_42dad_row3_col0, #T_42dad_row3_col5, #T_42dad_row4_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_42dad_row0_col5 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_42dad_row1_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_42dad_row1_col5, #T_42dad_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_42dad_row2_col5 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_42dad_row3_col2 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_42dad_row4_col2 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_42dad_row4_col5 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_42dad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42dad_level0_col0" class="col_heading level0 col0" >stop_year</th>
#       <th id="T_42dad_level0_col1" class="col_heading level0 col1" >stop_month</th>
#       <th id="T_42dad_level0_col2" class="col_heading level0 col2" >stop_hour</th>
#       <th id="T_42dad_level0_col3" class="col_heading level0 col3" >stop_daytime</th>
#       <th id="T_42dad_level0_col4" class="col_heading level0 col4" >driver_gender</th>
#       <th id="T_42dad_level0_col5" class="col_heading level0 col5" >driver_age</th>
#       <th id="T_42dad_level0_col6" class="col_heading level0 col6" >driver_race</th>
#       <th id="T_42dad_level0_col7" class="col_heading level0 col7" >violation_raw</th>
#       <th id="T_42dad_level0_col8" class="col_heading level0 col8" >violation</th>
#       <th id="T_42dad_level0_col9" class="col_heading level0 col9" >search_conducted</th>
#       <th id="T_42dad_level0_col10" class="col_heading level0 col10" >stop_outcome</th>
#       <th id="T_42dad_level0_col11" class="col_heading level0 col11" >is_arrested</th>
#       <th id="T_42dad_level0_col12" class="col_heading level0 col12" >stop_duration</th>
#       <th id="T_42dad_level0_col13" class="col_heading level0 col13" >drugs_related_stop</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42dad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42dad_row0_col0" class="data row0 col0" >2005</td>
#       <td id="T_42dad_row0_col1" class="data row0 col1" >Jan</td>
#       <td id="T_42dad_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_42dad_row0_col3" class="data row0 col3" >Night</td>
#       <td id="T_42dad_row0_col4" class="data row0 col4" >Male</td>
#       <td id="T_42dad_row0_col5" class="data row0 col5" >20</td>
#       <td id="T_42dad_row0_col6" class="data row0 col6" >White</td>
#       <td id="T_42dad_row0_col7" class="data row0 col7" >Speeding</td>
#       <td id="T_42dad_row0_col8" class="data row0 col8" >Speeding</td>
#       <td id="T_42dad_row0_col9" class="data row0 col9" >False</td>
#       <td id="T_42dad_row0_col10" class="data row0 col10" >Citation</td>
#       <td id="T_42dad_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_42dad_row0_col12" class="data row0 col12" >0-15 Min</td>
#       <td id="T_42dad_row0_col13" class="data row0 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_42dad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_42dad_row1_col0" class="data row1 col0" >2005</td>
#       <td id="T_42dad_row1_col1" class="data row1 col1" >Jan</td>
#       <td id="T_42dad_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_42dad_row1_col3" class="data row1 col3" >Morning</td>
#       <td id="T_42dad_row1_col4" class="data row1 col4" >Male</td>
#       <td id="T_42dad_row1_col5" class="data row1 col5" >40</td>
#       <td id="T_42dad_row1_col6" class="data row1 col6" >White</td>
#       <td id="T_42dad_row1_col7" class="data row1 col7" >Speeding</td>
#       <td id="T_42dad_row1_col8" class="data row1 col8" >Speeding</td>
#       <td id="T_42dad_row1_col9" class="data row1 col9" >False</td>
#       <td id="T_42dad_row1_col10" class="data row1 col10" >Citation</td>
#       <td id="T_42dad_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_42dad_row1_col12" class="data row1 col12" >0-15 Min</td>
#       <td id="T_42dad_row1_col13" class="data row1 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_42dad_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_42dad_row2_col0" class="data row2 col0" >2005</td>
#       <td id="T_42dad_row2_col1" class="data row2 col1" >Jan</td>
#       <td id="T_42dad_row2_col2" class="data row2 col2" >23</td>
#       <td id="T_42dad_row2_col3" class="data row2 col3" >Night</td>
#       <td id="T_42dad_row2_col4" class="data row2 col4" >Male</td>
#       <td id="T_42dad_row2_col5" class="data row2 col5" >33</td>
#       <td id="T_42dad_row2_col6" class="data row2 col6" >White</td>
#       <td id="T_42dad_row2_col7" class="data row2 col7" >Speeding</td>
#       <td id="T_42dad_row2_col8" class="data row2 col8" >Speeding</td>
#       <td id="T_42dad_row2_col9" class="data row2 col9" >False</td>
#       <td id="T_42dad_row2_col10" class="data row2 col10" >Citation</td>
#       <td id="T_42dad_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_42dad_row2_col12" class="data row2 col12" >0-15 Min</td>
#       <td id="T_42dad_row2_col13" class="data row2 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_42dad_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_42dad_row3_col0" class="data row3 col0" >2005</td>
#       <td id="T_42dad_row3_col1" class="data row3 col1" >Feb</td>
#       <td id="T_42dad_row3_col2" class="data row3 col2" >17</td>
#       <td id="T_42dad_row3_col3" class="data row3 col3" >Afternoon</td>
#       <td id="T_42dad_row3_col4" class="data row3 col4" >Male</td>
#       <td id="T_42dad_row3_col5" class="data row3 col5" >19</td>
#       <td id="T_42dad_row3_col6" class="data row3 col6" >White</td>
#       <td id="T_42dad_row3_col7" class="data row3 col7" >Call for Service</td>
#       <td id="T_42dad_row3_col8" class="data row3 col8" >Other</td>
#       <td id="T_42dad_row3_col9" class="data row3 col9" >False</td>
#       <td id="T_42dad_row3_col10" class="data row3 col10" >Arrest Driver</td>
#       <td id="T_42dad_row3_col11" class="data row3 col11" >True</td>
#       <td id="T_42dad_row3_col12" class="data row3 col12" >16-30 Min</td>
#       <td id="T_42dad_row3_col13" class="data row3 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_42dad_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_42dad_row4_col0" class="data row4 col0" >2005</td>
#       <td id="T_42dad_row4_col1" class="data row4 col1" >Mar</td>
#       <td id="T_42dad_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_42dad_row4_col3" class="data row4 col3" >Morning</td>
#       <td id="T_42dad_row4_col4" class="data row4 col4" >Female</td>
#       <td id="T_42dad_row4_col5" class="data row4 col5" >21</td>
#       <td id="T_42dad_row4_col6" class="data row4 col6" >White</td>
#       <td id="T_42dad_row4_col7" class="data row4 col7" >Speeding</td>
#       <td id="T_42dad_row4_col8" class="data row4 col8" >Speeding</td>
#       <td id="T_42dad_row4_col9" class="data row4 col9" >False</td>
#       <td id="T_42dad_row4_col10" class="data row4 col10" >Citation</td>
#       <td id="T_42dad_row4_col11" class="data row4 col11" >False</td>
#       <td id="T_42dad_row4_col12" class="data row4 col12" >0-15 Min</td>
#       <td id="T_42dad_row4_col13" class="data row4 col13" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
for column in police:
    print("Frequancy of "  + column + " column :")
    print(police[column].value_counts())
    print("-------------------------------------------\n")
# Out:
# Frequancy of stop_year column :
# 2012    10383
# 2006    10095
# 2007     8843
# 2014     8812
# 2015     8197
# 2008     8127
# 2011     7572
# 2013     7407
# 2009     7230
# 2010     6988
# 2005     2482
# Name: stop_year, dtype: int64
# -------------------------------------------
#
# Frequancy of stop_month column :
# Jan     7929
# May     7463
# Nov     7400
# Mar     7295
# Oct     7269
# June    7160
# Aug     7154
# Apr     7094
# July    7059
# Sept    6987
# Dec     6722
# Feb     6604
# Name: stop_month, dtype: int64
# -------------------------------------------
#
# Frequancy of stop_hour column :
# 10    6976
# 9     6442
# 11    5567
# 14    5339
# 23    5240
# 8     4930
# 0     4837
# 13    4601
# 15    4569
# 7     4359
# 1     4007
# 16    3598
# 12    3385
# 22    3211
# 6     3195
# 20    3156
# 17    2713
# 2     2710
# 19    2440
# 18    2040
# 21    1350
# 3     1067
# 4      216
# 5      188
# Name: stop_hour, dtype: int64
# -------------------------------------------
#
# Frequancy of stop_daytime column :
# Morning      31469
# Afternoon    24205
# Night        21476
# Evening       8986
# Name: stop_daytime, dtype: int64
# -------------------------------------------
#
# Frequancy of driver_gender column :
# Male      62691
# Female    23445
# Name: driver_gender, dtype: int64
# -------------------------------------------
#
# Frequancy of driver_age column :
# 22    4111
# 21    4046
# 23    3973
# 20    3780
# 24    3766
#       ...
# 88       2
# 99       1
# 89       1
# 94       1
# 90       1
# Name: driver_age, Length: 78, dtype: int64
# -------------------------------------------
#
# Frequancy of driver_race column :
# White       61966
# Black       12199
# Hispanic     9477
# Asian        2255
# Other         239
# Name: driver_race, dtype: int64
# -------------------------------------------
#
# Frequancy of violation_raw column :
# Speeding                            48318
# Other Traffic Violation             16172
# Equipment/Inspection Violation      10989
# Registration Violation               3412
# Seatbelt Violation                   2946
# Special Detail/Directed Patrol       2449
# Call for Service                     1287
# Violation of City/Town Ordinance      211
# Motorist Assist/Courtesy              202
# APB                                    79
# Suspicious Person                      56
# Warrant                                15
# Name: violation_raw, dtype: int64
# -------------------------------------------
#
# Frequancy of violation column :
# Speeding               48318
# Moving violation       16172
# Equipment              10989
# Other                   4299
# Registration/plates     3412
# Seat belt               2946
# Name: violation, dtype: int64
# -------------------------------------------
#
# Frequancy of search_conducted column :
# False    82949
# True      3187
# Name: search_conducted, dtype: int64
# -------------------------------------------
#
# Frequancy of stop_outcome column :
# Citation            76776
# Warning              5287
# Arrest Driver        2538
# N/D                   590
# No Action             588
# Arrest Passenger      357
# Name: stop_outcome, dtype: int64
# -------------------------------------------
#
# Frequancy of is_arrested column :
# False    83241
# True      2895
# Name: is_arrested, dtype: int64
# -------------------------------------------
#
# Frequancy of stop_duration column :
# 0-15 Min     69366
# 16-30 Min    13566
# 30+ Min       3202
# 2                1
# 1                1
# Name: stop_duration, dtype: int64
# -------------------------------------------
#
# Frequancy of drugs_related_stop column :
# False    85322
# True       814
# Name: drugs_related_stop, dtype: int64
# -------------------------------------------

# %%
police = police[police['stop_outcome'] != 'N/D']
police['stop_outcome'].value_counts()
# Out:
# Citation            76776
# Warning              5287
# Arrest Driver        2538
# No Action             588
# Arrest Passenger      357
# Name: stop_outcome, dtype: int64

# %%
police = police[police['stop_duration'] != '2']
police = police[police['stop_duration'] != '1']
police['stop_duration'].value_counts()
# Out:
# 0-15 Min     68847
# 16-30 Min    13511
# 30+ Min       3186
# Name: stop_duration, dtype: int64

# %%
police.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_7b4f2_row0_col0, #T_7b4f2_row0_col2, #T_7b4f2_row1_col0, #T_7b4f2_row2_col0, #T_7b4f2_row3_col0, #T_7b4f2_row3_col5, #T_7b4f2_row4_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7b4f2_row0_col5 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_7b4f2_row1_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_7b4f2_row1_col5, #T_7b4f2_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7b4f2_row2_col5 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_7b4f2_row3_col2 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_7b4f2_row4_col2 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_7b4f2_row4_col5 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_7b4f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b4f2_level0_col0" class="col_heading level0 col0" >stop_year</th>
#       <th id="T_7b4f2_level0_col1" class="col_heading level0 col1" >stop_month</th>
#       <th id="T_7b4f2_level0_col2" class="col_heading level0 col2" >stop_hour</th>
#       <th id="T_7b4f2_level0_col3" class="col_heading level0 col3" >stop_daytime</th>
#       <th id="T_7b4f2_level0_col4" class="col_heading level0 col4" >driver_gender</th>
#       <th id="T_7b4f2_level0_col5" class="col_heading level0 col5" >driver_age</th>
#       <th id="T_7b4f2_level0_col6" class="col_heading level0 col6" >driver_race</th>
#       <th id="T_7b4f2_level0_col7" class="col_heading level0 col7" >violation_raw</th>
#       <th id="T_7b4f2_level0_col8" class="col_heading level0 col8" >violation</th>
#       <th id="T_7b4f2_level0_col9" class="col_heading level0 col9" >search_conducted</th>
#       <th id="T_7b4f2_level0_col10" class="col_heading level0 col10" >stop_outcome</th>
#       <th id="T_7b4f2_level0_col11" class="col_heading level0 col11" >is_arrested</th>
#       <th id="T_7b4f2_level0_col12" class="col_heading level0 col12" >stop_duration</th>
#       <th id="T_7b4f2_level0_col13" class="col_heading level0 col13" >drugs_related_stop</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b4f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b4f2_row0_col0" class="data row0 col0" >2005</td>
#       <td id="T_7b4f2_row0_col1" class="data row0 col1" >Jan</td>
#       <td id="T_7b4f2_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_7b4f2_row0_col3" class="data row0 col3" >Night</td>
#       <td id="T_7b4f2_row0_col4" class="data row0 col4" >Male</td>
#       <td id="T_7b4f2_row0_col5" class="data row0 col5" >20</td>
#       <td id="T_7b4f2_row0_col6" class="data row0 col6" >White</td>
#       <td id="T_7b4f2_row0_col7" class="data row0 col7" >Speeding</td>
#       <td id="T_7b4f2_row0_col8" class="data row0 col8" >Speeding</td>
#       <td id="T_7b4f2_row0_col9" class="data row0 col9" >False</td>
#       <td id="T_7b4f2_row0_col10" class="data row0 col10" >Citation</td>
#       <td id="T_7b4f2_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_7b4f2_row0_col12" class="data row0 col12" >0-15 Min</td>
#       <td id="T_7b4f2_row0_col13" class="data row0 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7b4f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7b4f2_row1_col0" class="data row1 col0" >2005</td>
#       <td id="T_7b4f2_row1_col1" class="data row1 col1" >Jan</td>
#       <td id="T_7b4f2_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_7b4f2_row1_col3" class="data row1 col3" >Morning</td>
#       <td id="T_7b4f2_row1_col4" class="data row1 col4" >Male</td>
#       <td id="T_7b4f2_row1_col5" class="data row1 col5" >40</td>
#       <td id="T_7b4f2_row1_col6" class="data row1 col6" >White</td>
#       <td id="T_7b4f2_row1_col7" class="data row1 col7" >Speeding</td>
#       <td id="T_7b4f2_row1_col8" class="data row1 col8" >Speeding</td>
#       <td id="T_7b4f2_row1_col9" class="data row1 col9" >False</td>
#       <td id="T_7b4f2_row1_col10" class="data row1 col10" >Citation</td>
#       <td id="T_7b4f2_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_7b4f2_row1_col12" class="data row1 col12" >0-15 Min</td>
#       <td id="T_7b4f2_row1_col13" class="data row1 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7b4f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7b4f2_row2_col0" class="data row2 col0" >2005</td>
#       <td id="T_7b4f2_row2_col1" class="data row2 col1" >Jan</td>
#       <td id="T_7b4f2_row2_col2" class="data row2 col2" >23</td>
#       <td id="T_7b4f2_row2_col3" class="data row2 col3" >Night</td>
#       <td id="T_7b4f2_row2_col4" class="data row2 col4" >Male</td>
#       <td id="T_7b4f2_row2_col5" class="data row2 col5" >33</td>
#       <td id="T_7b4f2_row2_col6" class="data row2 col6" >White</td>
#       <td id="T_7b4f2_row2_col7" class="data row2 col7" >Speeding</td>
#       <td id="T_7b4f2_row2_col8" class="data row2 col8" >Speeding</td>
#       <td id="T_7b4f2_row2_col9" class="data row2 col9" >False</td>
#       <td id="T_7b4f2_row2_col10" class="data row2 col10" >Citation</td>
#       <td id="T_7b4f2_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_7b4f2_row2_col12" class="data row2 col12" >0-15 Min</td>
#       <td id="T_7b4f2_row2_col13" class="data row2 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7b4f2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7b4f2_row3_col0" class="data row3 col0" >2005</td>
#       <td id="T_7b4f2_row3_col1" class="data row3 col1" >Feb</td>
#       <td id="T_7b4f2_row3_col2" class="data row3 col2" >17</td>
#       <td id="T_7b4f2_row3_col3" class="data row3 col3" >Afternoon</td>
#       <td id="T_7b4f2_row3_col4" class="data row3 col4" >Male</td>
#       <td id="T_7b4f2_row3_col5" class="data row3 col5" >19</td>
#       <td id="T_7b4f2_row3_col6" class="data row3 col6" >White</td>
#       <td id="T_7b4f2_row3_col7" class="data row3 col7" >Call for Service</td>
#       <td id="T_7b4f2_row3_col8" class="data row3 col8" >Other</td>
#       <td id="T_7b4f2_row3_col9" class="data row3 col9" >False</td>
#       <td id="T_7b4f2_row3_col10" class="data row3 col10" >Arrest Driver</td>
#       <td id="T_7b4f2_row3_col11" class="data row3 col11" >True</td>
#       <td id="T_7b4f2_row3_col12" class="data row3 col12" >16-30 Min</td>
#       <td id="T_7b4f2_row3_col13" class="data row3 col13" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7b4f2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7b4f2_row4_col0" class="data row4 col0" >2005</td>
#       <td id="T_7b4f2_row4_col1" class="data row4 col1" >Mar</td>
#       <td id="T_7b4f2_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_7b4f2_row4_col3" class="data row4 col3" >Morning</td>
#       <td id="T_7b4f2_row4_col4" class="data row4 col4" >Female</td>
#       <td id="T_7b4f2_row4_col5" class="data row4 col5" >21</td>
#       <td id="T_7b4f2_row4_col6" class="data row4 col6" >White</td>
#       <td id="T_7b4f2_row4_col7" class="data row4 col7" >Speeding</td>
#       <td id="T_7b4f2_row4_col8" class="data row4 col8" >Speeding</td>
#       <td id="T_7b4f2_row4_col9" class="data row4 col9" >False</td>
#       <td id="T_7b4f2_row4_col10" class="data row4 col10" >Citation</td>
#       <td id="T_7b4f2_row4_col11" class="data row4 col11" >False</td>
#       <td id="T_7b4f2_row4_col12" class="data row4 col12" >0-15 Min</td>
#       <td id="T_7b4f2_row4_col13" class="data row4 col13" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85544 entries, 0 to 91740
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_year           85544 non-null  int64
#  1   stop_month          85544 non-null  object
#  2   stop_hour           85544 non-null  int64
#  3   stop_daytime        85544 non-null  object
#  4   driver_gender       85544 non-null  object
#  5   driver_age          85544 non-null  int64
#  6   driver_race         85544 non-null  object
#  7   violation_raw       85544 non-null  object
#  8   violation           85544 non-null  object
#  9   search_conducted    85544 non-null  bool
#  10  stop_outcome        85544 non-null  object
#  11  is_arrested         85544 non-null  object
#  12  stop_duration       85544 non-null  object
#  13  drugs_related_stop  85544 non-null  bool
# dtypes: bool(2), int64(3), object(9)
# memory usage: 8.6+ MB

# %% [markdown]
# <a id="Insights 👀"></a>
# ### <p style="padding:5px;background-color:#f6cd04;margin:0;color:#0c4da3;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:200">  Insights 💡</p>

# %% [markdown]
# <div style = 'border : 5px solid #0c4da3; background-color:lightred;padding:10px'>
#
# ### <u><span style="color:#08306B">Upon initial inspection, the following is observed:</span></u>
#
#  -    We have now no missing & duplicated values.
#
#  -   The majority of features are categorical which we have `9` features numerical`['stop_month', 'stop_daytime', 'driver_gender', 'driver_race', 'violation_raw','violation','stop_outcome','is_arrested','stop_duration']` and the other numerical.
#
#  - We now have new columns also as `'stop_year','stop_month','stop_hour','stop_daytime'` that help to detect the time highly.
#
# - Most of the data are `Males`, also the most are `not arrested` and `don't have drugs_related_stop`.
